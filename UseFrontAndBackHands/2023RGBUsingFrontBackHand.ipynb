# %%
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/num40/2023Num40RGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/omote", 0)
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/ura", 1)
    glob_files("D:/過去の研究データ/2023hands/arai/right/omote", 2)
    glob_files("D:/過去の研究データ/2023hands/arai/right/ura", 3)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/omote", 4)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/ura", 5)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/omote", 6)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/ura", 7)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/omote", 8)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/ura", 9)
    glob_files("D:/過去の研究データ/2023hands/isii/right/omote", 10)
    glob_files("D:/過去の研究データ/2023hands/isii/right/ura", 11)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/omote", 12)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/ura", 13)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/omote", 14)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/ura", 15)
    glob_files("D:/過去の研究データ/2023hands/oono/right/omote", 16)
    glob_files("D:/過去の研究データ/2023hands/oono/right/ura", 17)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/omote", 18)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/ura", 19)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/omote", 20)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/ura", 21)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/omote", 22)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/ura", 23)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/omote", 24)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/ura", 25)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/omote", 26)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/ura", 27)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/omote", 28)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/ura", 29)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/omote", 30)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/ura", 31)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/omote", 32)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/ura", 33)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/omote", 34)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/ura", 35)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/omote", 36)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/ura", 37)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/omote", 38)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/ura", 39)
    np.savez(outfile, x = x,y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__=='__main__':
    main()

# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num40RGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/omote", 0)
    glob_files("D:/過去の研究データ/2023hands/arai/right/omote", 1)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/omote", 2)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/omote", 3)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/omote", 4)
    glob_files("D:/過去の研究データ/2023hands/isii/right/omote", 5)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/omote", 6)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/omote", 7)
    glob_files("D:/過去の研究データ/2023hands/oono/right/omote", 8)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/omote", 9)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/omote", 10)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/omote", 11)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/omote", 12)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/omote", 13)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/omote", 14)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/omote", 15)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/omote", 16)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/omote", 17)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/omote", 18)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/omote", 19)
    np.savez(outfile, x = x,y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__=='__main__':
    main()

# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num40RGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/ura", 0)
    glob_files("D:/過去の研究データ/2023hands/arai/right/ura", 1)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/ura", 2)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/ura", 3)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/ura", 4)
    glob_files("D:/過去の研究データ/2023hands/isii/right/ura", 5)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/ura", 6)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/ura", 7)
    glob_files("D:/過去の研究データ/2023hands/oono/right/ura", 8)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/ura", 9)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/ura", 10)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/ura", 11)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/ura", 12)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/ura", 13)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/ura", 14)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/ura", 15)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/ura", 16)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/ura", 17)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/ura", 18)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/ura", 19)
    np.savez(outfile, x = x,y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__=='__main__':
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
#写真データ読み込み
photos=np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/2023Num20RGB-128pix.npz')
x=photos['x']
y=photos['y']
#開始インデックス
idx=1900
#pyplotで出力
plt.figure(figsize=(10,10))
plt.axis("off")


for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis("off")
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])

#--------------------画像1枚をピックアップして保存する-----------------------------
#plt.savefig('./extract.jpg')
plt.show()

# %%
# %%time
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    model.summary()
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

# 変更必要
im_size = 128 
im_color = 3
in_shape = (im_size, im_size, im_color)
nb_classes = 40 

#変更必要
photos = np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/num40/2023Num40RGB-128pix.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_size, im_size, im_color)
x = x.astype('float32') / 255
y = keras.utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size = 0.9)

model = get_model(in_shape, nb_classes)


hist = model.fit(x_train, y_train,
          batch_size = 256, 
          epochs = 20,
          verbose = 1,
          validation_data = (x_test, y_test))

score = model.evaluate(x_test, y_test, verbose = 1)
print('正解率=', score[1], 'loss=', score[0])


plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

#変更必要
model.save_weights('D:/過去の研究データ/2023hdf/2023UsingFrontAndBackHands/40num/2023Num40RGB-128pixBatch256.hdf5')

# %%
#他人受入率評価用のプログラム 
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#閾値の設定⇒変更必要
thresh = 99.99999

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/test/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/test/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128 
im_color = 3 
in_shape = (im_size, im_size, im_color)
#変更必要
nb_classes = 40
#配列の最大値
max_score = 0.0

LABELS=["相澤さんの表","相澤さんの裏",
       "新井さんの表","新井さんの裏",
       "江波戸の表","江波戸の裏",
       "長谷川さんの表","長谷川さんの裏",
       "樋口さんの表","樋口さんの裏",
       "石井さんの表","石井さんの裏",
       "小島さんの表","小島さんの裏",
       "中村さんの表","中村さんの裏",
       "大野さんの表","大野さんの裏",
       "坂井さんの表","坂井さんの裏",
       "関根さんの表","関根さんの裏",
       "島田さんの表","島田さんの裏",
       "清水さんの表","清水さんの裏",
       "高橋さんの表","高橋さんの裏",
       "田中ひろきさんの表","田中ひろきさんの裏",
       "田中みゆさんの表","田中みゆさんの裏",
       "田中たいきさんの表","田中たいきさんの裏",
       "徳山さんの表","徳山さんの裏",
       "渡邉さんの表","渡邉さんの裏",
       "山口さんの表","山口さんの裏"]

model = get_model(in_shape, nb_classes)
#変更必要
model.load_weights('D:/過去の研究データ/2023hdf/2023UsingFrontAndBackHands/40num/2023Num40RGB-128pixBatch256.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 
            
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size)) 
    plt.imshow(result_img)
    plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < thresh and ("omote" in path): 
        omoteNotPercent.append(per)
    elif per < thresh and ("ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS[idx_omote].split("の")
    uraPerson = LABELS[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= thresh and per_ura >= thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS[idx_omote], "裏:", LABELS[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS[idx_omote], " 裏の手:", LABELS[idx_ura], "でした" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        #lの値はnumbersの個数によって変更の可否が決まる
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    omotenotpass = len(omoteNotPercent) / 100
    omotepass = (100 - len(omoteNotPercent)) / 100
    uranotpass = len(uraNotPercent) / 100
    urapass = (100 - len(uraNotPercent)) / 100
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
    print("表の手だけで未学習の手を閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    print("表の手だけで未学習の手を閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    print("裏の手だけで未学習の手を閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    print("裏の手だけで未学習の手を閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    print("閾値以上の最大値は" + str(max_score)) 
    try:
        print("閾値以上の最小値は" + str(min(passpercent))) 
    except:
        pass

# %%
#本人受入率評価用のプログラム
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
      "arai/right/omote",
      "ebato/right/omote",
      "hasegawa/right/omote",
      "higuchi/right/omote",
      "isii/right/omote",
      "kojima/right/omote",
      "nakamura/right/omote",
      "oono/right/omote",
      "sakai/right/omote",
      "sekine/right/omote",
      "shimada/right/omote",
      "shimizu/right/omote",
      "takahashi/right/omote",
      "tanakahiroki/right/omote",
      "tanakamiyu/right/omote",
      "tanakataiki/right/omote",
      "tokuyama/right/omote",
      "watanabe/right/omote",
      "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
      "arai/right/ura",
      "ebato/right/ura",
      "hasegawa/right/ura",
      "higuchi/right/ura",
      "isii/right/ura",
      "kojima/right/ura",
      "nakamura/right/ura",
      "oono/right/ura",
      "sakai/right/ura",
      "sekine/right/ura",
      "shimada/right/ura",
      "shimizu/right/ura",
      "takahashi/right/ura",
      "tanakahiroki/right/ura",
      "tanakamiyu/right/ura",
      "tanakataiki/right/ura",
      "tokuyama/right/ura",
      "watanabe/right/ura",
      "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []
#閾値の設定⇒変更必要
thresh = 99.99999

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023handstest/" + str(omote[k]) + "/rgb" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023handstest/" + str(ura[k]) + "/rgb" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 3 
in_shape = (im_size, im_size, im_color)
nb_classes = 40
#配列の最大値
max_score = 0.0

#学習した人のラベル
LABELS=["相澤さんの表","相澤さんの裏",
       "新井さんの表","新井さんの裏",
       "江波戸の表","江波戸の裏",
       "長谷川さんの表","長谷川さんの裏",
       "樋口さんの表","樋口さんの裏",
       "石井さんの表","石井さんの裏",
       "小島さんの表","小島さんの裏",
       "中村さんの表","中村さんの裏",
       "大野さんの表","大野さんの裏",
       "坂井さんの表","坂井さんの裏",
       "関根さんの表","関根さんの裏",
       "島田さんの表","島田さんの裏",
       "清水さんの表","清水さんの裏",
       "高橋さんの表","高橋さんの裏",
       "田中ひろきさんの表","田中ひろきさんの裏",
       "田中みゆさんの表","田中みゆさんの裏",
       "田中たいきさんの表","田中たいきさんの裏",
       "徳山さんの表","徳山さんの裏",
       "渡邉さんの表","渡邉さんの裏",
       "山口さんの表","山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model = get_model(in_shape, nb_classes)
#変更必要
model.load_weights('D:/過去の研究データ/2023hdf/2023UsingFrontAndBackHands/40num/2023Num40RGB-128pixBatch256.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size))
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < thresh and ("omote" in path):
        omoteNotPercent.append(per)
    elif per < thresh and ("ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return(idx, per)
            

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS[idx_omote].split("の")
    uraPerson = LABELS[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= thresh and per_ura >= thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS[idx_omote], "裏:", LABELS[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")
        #上記条件を満たした時ラベルの中身が一致しているかどうかを確認
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS[idx_omote], " 裏の手:", LABELS[idx_ura], "でした" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #check_photo_strに接続
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
        
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    omotenotpass = len(omoteNotPercent) / 200
    omotepass = (200 - len(omoteNotPercent)) / 200
    uranotpass = len(uraNotPercent) / 200
    urapass = (200 - len(uraNotPercent)) / 200
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    print("表の手だけを閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    print("表の手だけを閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    print("裏の手だけを閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    print("裏の手だけを閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    print("閾値以上の最大値は" + str(max_score))
    try:
        print("閾値以上の最小値は" + str(min(passpercent)))
    except:
        pass
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
    #他人受入率の算出時に受け入れてしまった個数
    print(FAR)
    #学習済みの人の手の中で他人を受入れてしまった人の個数
    print(len(notIncludeLABEL))
