# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20FrontRGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023sheetsHands/aizawa/right/omote", 0)
    glob_files("D:/過去の研究データ/2023sheetsHands/arai/right/omote", 1)
    glob_files("D:/過去の研究データ/2023sheetsHands/ebato/right/omote", 2)
    glob_files("D:/過去の研究データ/2023sheetsHands/hasegawa/right/omote", 3)
    glob_files("D:/過去の研究データ/2023sheetsHands/higuchi/right/omote", 4)
    glob_files("D:/過去の研究データ/2023sheetsHands/isii/right/omote", 5)
    glob_files("D:/過去の研究データ/2023sheetsHands/kojima/right/omote", 6)
    glob_files("D:/過去の研究データ/2023sheetsHands/nakamura/right/omote", 7)
    glob_files("D:/過去の研究データ/2023sheetsHands/oono/right/omote", 8)
    glob_files("D:/過去の研究データ/2023sheetsHands/sakai/right/omote", 9)
    glob_files("D:/過去の研究データ/2023sheetsHands/sekine/right/omote", 10)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimada/right/omote", 11)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimizu/right/omote", 12)
    glob_files("D:/過去の研究データ/2023sheetsHands/takahashi/right/omote", 13)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakahiroki/right/omote", 14)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakamiyu/right/omote", 15)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakataiki/right/omote", 16)
    glob_files("D:/過去の研究データ/2023sheetsHands/tokuyama/right/omote", 17)
    glob_files("D:/過去の研究データ/2023sheetsHands/watanabe/right/omote", 18)
    glob_files("D:/過去の研究データ/2023sheetsHands/yamaguchi/right/omote", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label)
        
if __name__ == '__main__':
    main()
# Out:
# 保存しました:D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20FrontRGB-128pix.npz 2000
# [[[213 208 207]
#   [208 209 207]
#   [208 209 207]
#   ...
#   [212 213 211]
#   [210 211 209]
#   [211 212 210]]
#
#  [[213 208 207]
#   [208 209 207]
#   [208 209 207]
#   ...
#   [210 211 209]
#   [212 213 211]
#   [211 212 210]]
#
#  [[213 208 207]
#   [207 208 206]
#   [207 208 206]
#   ...
#   [210 211 209]
#   [210 211 209]
#   [209 210 208]]
#
#  ...
#
#  [[186 192 191]
#   [184 190 189]
#   [187 191 192]
#   ...
#   [180 186 185]
#   [180 186 185]
#   [179 185 184]]
#
#  [[184 188 189]
#   [183 187 188]
#   [184 188 189]
#   ...
#   [180 186 185]
#   [177 183 182]
#   [177 183 182]]
#
#  [[177 179 180]
#   [160 160 166]
#   [162 164 164]
#   ...
#   [139 145 140]
#   [246 252 251]
#   [  5  10   9]]] 0

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
#写真データ読み込み
photos=np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20FrontRGB-128pix.npz')
x=photos['x']
y=photos['y']
#開始インデックス
idx=7500
#pyplotで出力
plt.figure(figsize=(10,10))
plt.axis("off")


for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis("off")
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])

#--------------------画像1枚をピックアップして保存する-----------------------------
#plt.savefig('./extract.jpg')
plt.show()

# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20BackRGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023sheetsHands/aizawa/right/ura", 0)
    glob_files("D:/過去の研究データ/2023sheetsHands/arai/right/ura", 1)
    glob_files("D:/過去の研究データ/2023sheetsHands/ebato/right/ura", 2)
    glob_files("D:/過去の研究データ/2023sheetsHands/hasegawa/right/ura", 3)
    glob_files("D:/過去の研究データ/2023sheetsHands/higuchi/right/ura", 4)
    glob_files("D:/過去の研究データ/2023sheetsHands/isii/right/ura", 5)
    glob_files("D:/過去の研究データ/2023sheetsHands/kojima/right/ura", 6)
    glob_files("D:/過去の研究データ/2023sheetsHands/nakamura/right/ura", 7)
    glob_files("D:/過去の研究データ/2023sheetsHands/oono/right/ura", 8)
    glob_files("D:/過去の研究データ/2023sheetsHands/sakai/right/ura", 9)
    glob_files("D:/過去の研究データ/2023sheetsHands/sekine/right/ura", 10)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimada/right/ura", 11)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimizu/right/ura", 12)
    glob_files("D:/過去の研究データ/2023sheetsHands/takahashi/right/ura", 13)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakahiroki/right/ura", 14)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakamiyu/right/ura", 15)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakataiki/right/ura", 16)
    glob_files("D:/過去の研究データ/2023sheetsHands/tokuyama/right/ura", 17)
    glob_files("D:/過去の研究データ/2023sheetsHands/watanabe/right/ura", 18)
    glob_files("D:/過去の研究データ/2023sheetsHands/yamaguchi/right/ura", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__ == '__main__':
    main()
# Out:
# 保存しました:D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20BackRGB-128pix.npz 2000
# [[[211 211 211]
#   [213 213 213]
#   [213 213 213]
#   ...
#   [215 215 215]
#   [215 215 215]
#   [214 214 214]]
#
#  [[211 211 211]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [215 215 215]
#   [215 215 215]
#   [214 214 214]]
#
#  [[211 211 211]
#   [211 211 211]
#   [211 211 211]
#   ...
#   [214 214 214]
#   [215 215 215]
#   [215 215 215]]
#
#  ...
#
#  [[191 195 196]
#   [190 194 195]
#   [190 194 195]
#   ...
#   [183 187 188]
#   [185 189 190]
#   [185 189 190]]
#
#  [[190 194 195]
#   [190 194 195]
#   [190 194 195]
#   ...
#   [182 186 187]
#   [182 186 187]
#   [184 188 189]]
#
#  [[187 192 195]
#   [191 189 195]
#   [194 197 202]
#   ...
#   [192 196 197]
#   [ 62  65  69]
#   [ 50  53  57]]] 0

# %%
# %%time
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    model.summary()
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

# 変更必要
im_size = 128 
im_color = 3
in_shape = (im_size, im_size, im_color)
nb_classes = 20
hands = "Back"
batch = 256
#変更必要
photos = np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20' + hands + 'RGB-' + str(im_size) + 'pix.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_size, im_size, im_color)
x = x.astype('float32') / 255
y = keras.utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size = 0.9)

model = get_model(in_shape, nb_classes)


hist = model.fit(x_train, y_train,
          batch_size = batch, 
          epochs = 20,
          verbose = 1,
          validation_data = (x_test, y_test))

score = model.evaluate(x_test, y_test, verbose = 1)
print('正解率=', score[1], 'loss=', score[0])


plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()
#変更必要
model.save_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20' + hands + 'RGB-' + str(im_size) + 'pixBatch' + str(batch) + '.hdf5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\__init__.py in <module>
#      22 from keras import distribute
#      23
# ---> 24 from keras import models
#      25
#      26 from keras.engine.input_layer import Input
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\models\__init__.py in <module>
#      16 # pylint: disable=g-bad-import-order
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\engine\functional.py in <module>
#      29 from keras.engine import input_spec
#      30 from keras.engine import node as node_module
# ---> 31 from keras.engine import training as training_lib
#      32 from keras.engine import training_utils
#      33 from keras.saving.saved_model import json_utils
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\engine\training.py in <module>
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
# ---> 30 from keras.engine import compile_utils
#      31 from keras.engine import data_adapter
#      32 from keras.engine import input_layer as input_layer_module
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\engine\compile_utils.py in <module>
#      18 import copy
#      19 from keras import losses as losses_mod
# ---> 20 from keras import metrics as metrics_mod
#      21 from keras.utils import generic_utils
#      22 from keras.utils import losses_utils
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\metrics\__init__.py in <module>
#      31
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import MeanRelativeError
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\metrics\metrics.py in <module>
#      20 from typing import List, Tuple, Union
#      21
# ---> 22 from keras import activations
#      23 from keras import backend
#      24 from keras.dtensor import utils as dtensor_utils
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\activations.py in <module>
#      18
#      19 from keras import backend
# ---> 20 import keras.layers.activation as activation_layers
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\layers\__init__.py in <module>
#      25 from keras.engine.input_spec import InputSpec
#      26 from keras.engine.base_layer import Layer
# ---> 27 from keras.engine.base_preprocessing_layer import PreprocessingLayer
#      28
#      29 # Image preprocessing layers.
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\engine\base_preprocessing_layer.py in <module>
#      17 import abc
#      18
# ---> 19 from keras.engine import data_adapter
#      20 from keras.engine.base_layer import Layer
#      21 from keras.utils import version_utils
#
# c:\Users\LOLME\anaconda3\lib\site-packages\keras\engine\data_adapter.py in <module>
#      36
#      37 try:
# ---> 38   import pandas as pd  # pylint: disable=g-import-not-at-top
#      39 except ImportError:
#      40   pd = None
#
# c:\Users\LOLME\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     177
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     181
#
# c:\Users\LOLME\anaconda3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# c:\Users\LOLME\anaconda3\lib\site-packages\pandas\_testing.py in <module>
#    3052
#    3053
# -> 3054 cython_table = pd.core.base.SelectionMixin._cython_table.items()
#    3055
#    3056
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
#他人受入率評価用のプログラム 
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値以上で受入れられた確率が表と裏でそれぞれ格納-----追加1
omotePassPercent = []
uraPassPercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/test/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/test/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128 
im_color = 3 
in_shape = (im_size, im_size, im_color)
#変更必要
nb_classes = 20
#配列の最大値
max_score = 0.0
min_score = 0.0
#閾値の設定-----追加2
omote_thresh = 40.2
ura_thresh = 42.3
batch = "256"

LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]

model_front = get_model(in_shape, nb_classes)
model_back  = get_model(in_shape, nb_classes)
#変更必要
# model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
# model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 

def findminscore(per):
    global min_score
    if per != 100.0:
        if min_score <= per:
            min_score = per 

#表の評価画像のチェック関数            
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size)) 
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < omote_thresh and ("/omote" in path): 
        omoteNotPercent.append(per)
    elif per < ura_thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= omote_thresh and per_ura >= ura_thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        omotePassPercent.append(per_omote)#-----追加3
        uraPassPercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)

        findminscore(per_omote)
        findminscore(per_ura)
    
if __name__ == '__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        #lの値はnumbersの個数によって変更の可否が決まる
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(omotePassPercent)#-----追加4
    print(uraPassPercent)
    #他人拒否率の配列の中身を表示
    print(omoteNotPercent)
    print(uraNotPercent)
    print("RGB画像 " + str(im_size) + "px バッチサイズ" + str(batch))
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    omotenotpass = len(omoteNotPercent) / 100
    omotepass = (100 - len(omoteNotPercent)) / 100
    uranotpass = len(uraNotPercent) / 100
    urapass = (100 - len(uraNotPercent)) / 100
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
    # print("表の手だけで未学習の手を閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    # print("表の手だけで未学習の手を閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    # print("裏の手だけで未学習の手を閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    # print("裏の手だけで未学習の手を閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    try:
        print("表の手で閾値未満の最大値は" + str(max(omoteNotPercent)))#-----追加5
        print("裏の手で閾値未満の最大値は" + str(max(uraNotPercent)))
        print("表の平均値"+ str(np.mean(omoteNotPercent)))
        print("裏の平均値"+ str(np.mean(uraNotPercent)))
    except:
        pass
    try:
        print("表の手で閾値以上の最小値は" + str(min(omotePassPercent)))#-----追加6
        print("裏の手で閾値以上の最小値は" + str(min(uraPassPercent)))
    except:
        pass
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 可能性が表の手: 39.719438552856445 % 裏の手: 82.16588497161865 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 44.008445739746094 % 裏の手: 25.88476538658142 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 30.62862753868103 % 裏の手: 51.848798990249634 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 42.030683159828186 % 裏の手: 54.81390953063965 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 島田さんの裏 でした
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 66.61524772644043 % 裏の手: 22.420483827590942 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 70.42180895805359 % 裏の手: 41.91615879535675 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 島田さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 30.935943126678467 % 裏の手: 76.18491053581238 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 68.54992508888245 % 裏の手: 42.74333119392395 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 可能性が表の手: 20.881640911102295 % 裏の手: 65.51044583320618 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 79.11690473556519 % 裏の手: 63.33216428756714 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 可能性が表の手: 34.19197201728821 % 裏の手: 95.92283368110657 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 36.48654818534851 % 裏の手: 80.49848079681396 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 53.19729447364807 % 裏の手: 64.67350125312805 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 58.15826654434204 % 裏の手: 85.58095693588257 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 46.11329138278961 % 裏の手: 92.11671948432922 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 46.14750146865845 % 裏の手: 77.86812782287598 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 46.2115079164505 % 裏の手: 87.841796875 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 でした
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 63.92441391944885 % 裏の手: 82.65569806098938 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 37.07720637321472 % 裏の手: 47.53550589084625 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 44.43005621433258 % 裏の手: 83.48923325538635 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 39.84316885471344 % 裏の手: 48.47891330718994 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 30.115073919296265 % 裏の手: 82.7377438545227 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 33.668252825737 % 裏の手: 58.41740369796753 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 15.950964391231537 % 裏の手: 85.7367753982544 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 41.113194823265076 % 裏の手: 85.18716096878052 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 34.662699699401855 % 裏の手: 60.128092765808105 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 39.18093740940094 % 裏の手: 88.70823979377747 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 可能性が表の手: 66.40517115592957 % 裏の手: 94.40120458602905 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 34.407445788383484 % 裏の手: 64.38549757003784 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 24.022646248340607 % 裏の手: 86.21494174003601 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 高橋さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 32.82434046268463 % 裏の手: 50.193047523498535 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 徳山さんの裏 でした
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 25.94330608844757 % 裏の手: 43.648672103881836 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 清水さんの裏 でした
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 42.33314096927643 % 裏の手: 49.715229868888855 %なので認証します
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 62.27647662162781 % 裏の手: 32.77403116226196 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 27.009376883506775 % 裏の手: 34.468117356300354 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 16.327184438705444 % 裏の手: 28.203070163726807 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 清水さんの裏 でした
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 28.987371921539307 % 裏の手: 44.60724890232086 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 51.67693495750427 % 裏の手: 39.52566683292389 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 52.92799472808838 % 裏の手: 83.93078446388245 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 38.692569732666016 % 裏の手: 60.31252145767212 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 28.584983944892883 % 裏の手: 24.49541538953781 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 41.4840966463089 % 裏の手: 75.10643601417542 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 40.8098965883255 % 裏の手: 83.84153246879578 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 でした
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 43.10429096221924 % 裏の手: 55.35377860069275 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 でした
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 41.13840162754059 % 裏の手: 34.11675691604614 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 中村さんの裏 でした
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 43.561363220214844 % 裏の手: 74.78771209716797 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 37.81343400478363 % 裏の手: 43.73134672641754 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 でした
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 56.15334510803223 % 裏の手: 79.72838878631592 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 32.15213716030121 % 裏の手: 83.09422731399536 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 32.23933279514313 % 裏の手: 25.260326266288757 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 47.83381223678589 % 裏の手: 12.904942035675049 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 山口さんの裏 でした
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 37.69180178642273 % 裏の手: 7.725560665130615 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 新井さんの裏 でした
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 20.92284858226776 % 裏の手: 9.264066815376282 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 47.73249626159668 % 裏の手: 8.156052231788635 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.903098344802856 % 裏の手: 10.245166718959808 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.12360072135925 % 裏の手: 9.666944295167923 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 32.476428151130676 % 裏の手: 8.761946856975555 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 35.94196140766144 % 裏の手: 7.8171588480472565 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 19.736596941947937 % 裏の手: 16.278323531150818 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 可能性が表の手: 19.64506506919861 % 裏の手: 9.185544401407242 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 16.1174938082695 % 裏の手: 13.310007750988007 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 40.652650594711304 % 裏の手: 12.228289991617203 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 22.05328941345215 % 裏の手: 8.451801538467407 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 19.274845719337463 % 裏の手: 14.871948957443237 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 55.42626976966858 % 裏の手: 10.225972533226013 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 19.640038907527924 % 裏の手: 21.54989391565323 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 48.950207233428955 % 裏の手: 11.696907132863998 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 23.470738530158997 % 裏の手: 9.53601822257042 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.03098106384277 % 裏の手: 13.206003606319427 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 25.23004412651062 % 裏の手: 10.851215571165085 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 22.19228446483612 % 裏の手: 10.388339310884476 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 でした
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 23.944027721881866 % 裏の手: 7.564488798379898 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 29.169511795043945 % 裏の手: 8.824604004621506 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 32.083660364151 % 裏の手: 7.908523082733154 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 26.843106746673584 % 裏の手: 12.492768466472626 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 26.192304491996765 % 裏の手: 10.336307436227798 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 27.484196424484253 % 裏の手: 8.045218884944916 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 でした
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 30.57936429977417 % 裏の手: 9.185463935136795 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 でした
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 21.7180073261261 % 裏の手: 8.766122162342072 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 でした
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 20.884504914283752 % 裏の手: 7.009381800889969 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 関根さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 48.90821576118469 % 裏の手: 8.874034881591797 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 50.81641674041748 % 裏の手: 9.628573060035706 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 37.0735228061676 % 裏の手: 12.168599665164948 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 49.404746294021606 % 裏の手: 8.241921663284302 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 46.99404835700989 % 裏の手: 10.380031168460846 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 43.24311017990112 % 裏の手: 13.47668319940567 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 44.80656385421753 % 裏の手: 10.286498069763184 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 樋口さんの裏 でした
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 35.866475105285645 % 裏の手: 9.216135740280151 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 33.410632610321045 % 裏の手: 10.916899144649506 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 47.75628447532654 % 裏の手: 12.681812047958374 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 28.743529319763184 % 裏の手: 30.915677547454834 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 74.59912896156311 % 裏の手: 61.34238839149475 %なので認証します
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 50.104206800460815 % 裏の手: 82.14743137359619 %なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 95.56227922439575 % 裏の手: 64.9700403213501 %なので認証します
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 51.774436235427856 % 裏の手: 53.254759311676025 %なので認証します
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 44.71365511417389 % 裏の手: 93.78702640533447 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 清水さんの裏 でした
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 71.67924046516418 % 裏の手: 92.17135310173035 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 49.910858273506165 % 裏の手: 96.7305064201355 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 45.641106367111206 % 裏の手: 29.740548133850098 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 53.71285080909729 % 裏の手: 67.0499324798584 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
# [42.33314096927643, 74.59912896156311, 50.104206800460815, 95.56227922439575, 51.774436235427856]
# [49.715229868888855, 61.34238839149475, 82.14743137359619, 64.9700403213501, 53.254759311676025]
# [39.719438552856445, 30.62862753868103, 30.935943126678467, 20.881640911102295, 34.19197201728821, 36.48654818534851, 37.07720637321472, 39.84316885471344, 30.115073919296265, 33.668252825737, 15.950964391231537, 34.662699699401855, 39.18093740940094, 34.407445788383484, 24.022646248340607, 32.82434046268463, 25.94330608844757, 27.009376883506775, 16.327184438705444, 28.987371921539307, 38.692569732666016, 28.584983944892883, 37.81343400478363, 32.15213716030121, 32.23933279514313, 37.69180178642273, 20.92284858226776, 39.903098344802856, 39.12360072135925, 32.476428151130676, 35.94196140766144, 19.736596941947937, 19.64506506919861, 16.1174938082695, 22.05328941345215, 19.274845719337463, 19.640038907527924, 23.470738530158997, 39.03098106384277, 25.23004412651062, 22.19228446483612, 23.944027721881866, 29.169511795043945, 32.083660364151, 26.843106746673584, 26.192304491996765, 27.484196424484253, 30.57936429977417, 21.7180073261261, 20.884504914283752, 37.0735228061676, 35.866475105285645, 33.410632610321045, 28.743529319763184]
# [25.88476538658142, 22.420483827590942, 41.91615879535675, 32.77403116226196, 34.468117356300354, 28.203070163726807, 39.52566683292389, 24.49541538953781, 34.11675691604614, 25.260326266288757, 12.904942035675049, 7.725560665130615, 9.264066815376282, 8.156052231788635, 10.245166718959808, 9.666944295167923, 8.761946856975555, 7.8171588480472565, 16.278323531150818, 9.185544401407242, 13.310007750988007, 12.228289991617203, 8.451801538467407, 14.871948957443237, 10.225972533226013, 21.54989391565323, 11.696907132863998, 9.53601822257042, 13.206003606319427, 10.851215571165085, 10.388339310884476, 7.564488798379898, 8.824604004621506, 7.908523082733154, 12.492768466472626, 10.336307436227798, 8.045218884944916, 9.185463935136795, 8.766122162342072, 7.009381800889969, 8.874034881591797, 9.628573060035706, 12.168599665164948, 8.241921663284302, 10.380031168460846, 13.47668319940567, 10.286498069763184, 9.216135740280151, 10.916899144649506, 12.681812047958374, 30.915677547454834, 29.740548133850098]
# RGB画像 128px バッチサイズ256
# 他人受入に用いる個数10
# 閾値未満で識別したテスト数190
# 表の手だけで閾値未満で識別したテスト数54
# 裏の手だけで閾値未満で識別したテスト数52
# ================================================
# 他人拒否率95.0%
# 他人受入率5.0%
# 表の手で閾値未満の最大値は39.903098344802856
# 裏の手で閾値未満の最大値は41.91615879535675
# 表の平均値29.42204748590787
# 裏の平均値15.231676729252705
# 表の手で閾値以上の最小値は42.33314096927643
# 裏の手で閾値以上の最小値は49.715229868888855

# %%
#本人受入率評価用のプログラム
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
      "arai/right/omote",
      "ebato/right/omote",
      "hasegawa/right/omote",
      "higuchi/right/omote",
      "isii/right/omote",
      "kojima/right/omote",
      "nakamura/right/omote",
      "oono/right/omote",
      "sakai/right/omote",
      "sekine/right/omote",
      "shimada/right/omote",
      "shimizu/right/omote",
      "takahashi/right/omote",
      "tanakahiroki/right/omote",
      "tanakamiyu/right/omote",
      "tanakataiki/right/omote",
      "tokuyama/right/omote",
      "watanabe/right/omote",
      "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
      "arai/right/ura",
      "ebato/right/ura",
      "hasegawa/right/ura",
      "higuchi/right/ura",
      "isii/right/ura",
      "kojima/right/ura",
      "nakamura/right/ura",
      "oono/right/ura",
      "sakai/right/ura",
      "sekine/right/ura",
      "shimada/right/ura",
      "shimizu/right/ura",
      "takahashi/right/ura",
      "tanakahiroki/right/ura",
      "tanakamiyu/right/ura",
      "tanakataiki/right/ura",
      "tokuyama/right/ura",
      "watanabe/right/ura",
      "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#閾値以上で受入れられた確率が表と裏でそれぞれ格納-----追加1
omotePassPercent = []
uraPassPercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023handstest/" + str(omote[k]) + "/rgb" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023handstest/" + str(ura[k]) + "/rgb" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 3 
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
#閾値の設定-----追加2
omote_thresh = 40.2
ura_thresh = 42.3
batch = "256"

#学習した人のラベル
LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)
#変更必要
# model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
# model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size))
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    else:
        pass
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < omote_thresh and ("/omote" in path):
        omoteNotPercent.append(per)
    elif per < ura_thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return(idx, per)
            

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= omote_thresh and per_ura >= ura_thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")
        #上記条件を満たした時ラベルの中身が一致しているかどうかを確認
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS_Front[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Front[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS_Back[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Back[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        omotePassPercent.append(per_omote)#-----追加3
        uraPassPercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #本人受入率の配列の中身を表示
    print(omotePassPercent)#-----追加4
    print(uraPassPercent)
    #本人拒否率の配列の中身を表示
    print(omoteNotPercent)
    print(uraNotPercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    omotenotpass = len(omoteNotPercent) / 200
    omotepass = (200 - len(omoteNotPercent)) / 200
    uranotpass = len(uraNotPercent) / 200
    urapass = (200 - len(uraNotPercent)) / 200
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    # print("表の手だけを閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    # print("表の手だけを閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    # print("裏の手だけを閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    # print("裏の手だけを閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    try:
        print("表の手で閾値未満の最大値は" + str(max(omoteNotPercent)))#-----追加5
        print("裏の手で閾値未満の最大値は" + str(max(uraNotPercent)))
        print("表の平均値"+ str(np.mean(omoteNotPercent)))
        print("裏の平均値"+ str(np.mean(uraNotPercent)))
    except:
        pass
    try:
        print("表の手で閾値以上の最小値は" + str(min(omotePassPercent)))#-----追加6
        print("裏の手で閾値以上の最小値は" + str(min(uraPassPercent)))
    except:
        pass
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
    #他人受入率の算出時に受け入れてしまった個数
    print(FAR)
    #学習済みの人の手の中で他人を受入れてしまった人の個数
    print(len(notIncludeLABEL))
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 可能性が表の手: 52.26324796676636 % 裏の手: 14.468125998973846 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 55.80375790596008 % 裏の手: 25.408393144607544 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 65.4345691204071 % 裏の手: 29.567694664001465 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 31.9964736700058 % 裏の手: 16.890564560890198 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 74.08157587051392 % 裏の手: 14.367461204528809 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 31.972679495811462 % 裏の手: 11.525516211986542 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 71.4996874332428 % 裏の手: 29.303893446922302 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 79.93721961975098 % 裏の手: 18.540604412555695 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 可能性が表の手: 71.29729986190796 % 裏の手: 29.918202757835388 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 65.30008316040039 % 裏の手: 25.817760825157166 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 60.61587333679199 % 裏の手: 9.61218774318695 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 72.09872007369995 % 裏の手: 13.19323480129242 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 70.8163321018219 % 裏の手: 15.260852873325348 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 62.429314851760864 % 裏の手: 10.535302013158798 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 72.8137731552124 % 裏の手: 13.735054433345795 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 76.73750519752502 % 裏の手: 13.723474740982056 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 74.94209408760071 % 裏の手: 9.182682633399963 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 64.75030779838562 % 裏の手: 13.917818665504456 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 73.68191480636597 % 裏の手: 12.316490709781647 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 74.85242486000061 % 裏の手: 15.545935928821564 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 43.890419602394104 % 裏の手: 21.429455280303955 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 35.59219837188721 % 裏の手: 11.637281626462936 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 39.759451150894165 % 裏の手: 17.98054426908493 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 52.21567749977112 % 裏の手: 22.00184166431427 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 29.445210099220276 % 裏の手: 15.108685195446014 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 江波戸の裏 でした
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 42.87298619747162 % 裏の手: 16.83327555656433 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 33.837202191352844 % 裏の手: 15.607266128063202 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 27.25262939929962 % 裏の手: 23.793886601924896 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 28.950214385986328 % 裏の手: 20.907263457775116 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 48.286694288253784 % 裏の手: 17.336788773536682 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 60.251837968826294 % 裏の手: 14.25275057554245 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 59.797126054763794 % 裏の手: 27.576297521591187 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 63.08615803718567 % 裏の手: 17.574071884155273 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 64.7052526473999 % 裏の手: 23.13857227563858 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 67.56069660186768 % 裏の手: 22.40491211414337 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 67.09471344947815 % 裏の手: 21.445955336093903 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 66.79796576499939 % 裏の手: 22.45831936597824 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 76.8183171749115 % 裏の手: 30.66234588623047 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 70.9635078907013 % 裏の手: 18.87807995080948 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 68.6427116394043 % 裏の手: 27.392396330833435 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.95562791824341 % 裏の手: 26.716327667236328 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 34.10504758358002 % 裏の手: 17.990605533123016 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 44.118356704711914 % 裏の手: 27.263712882995605 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 44.70559060573578 % 裏の手: 19.53209489583969 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 61.149805784225464 % 裏の手: 24.58507865667343 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 33.62705111503601 % 裏の手: 27.075761556625366 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 32.58487284183502 % 裏の手: 8.44854786992073 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 関根さんの裏 でした
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 64.59696292877197 % 裏の手: 35.62349081039429 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 63.456594944000244 % 裏の手: 31.93250000476837 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 46.08961641788483 % 裏の手: 20.650891959667206 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 75.89200735092163 % 裏の手: 12.207993119955063 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 71.24409675598145 % 裏の手: 18.43816637992859 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 71.66325449943542 % 裏の手: 19.565248489379883 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 66.54092669487 % 裏の手: 19.05355304479599 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 69.85172033309937 % 裏の手: 16.660606861114502 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 76.57362818717957 % 裏の手: 18.707166612148285 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 70.8694338798523 % 裏の手: 18.571476638317108 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 88.58869671821594 % 裏の手: 17.75652766227722 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 77.06138491630554 % 裏の手: 18.194863200187683 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 79.74211573600769 % 裏の手: 15.077929198741913 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 76.78728699684143 % 裏の手: 35.31932234764099 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 89.686119556427 % 裏の手: 52.26408243179321 %なので認証します
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 84.0026319026947 % 裏の手: 51.78544521331787 %なので認証します
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 96.17188572883606 % 裏の手: 43.78758370876312 %なので認証します
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 79.88094687461853 % 裏の手: 65.62094688415527 %なので認証します
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 88.57828378677368 % 裏の手: 54.72198724746704 %なので認証します
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 96.05751037597656 % 裏の手: 49.93578791618347 %なので認証します
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 72.43601679801941 % 裏の手: 39.30482864379883 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 73.44082593917847 % 裏の手: 39.921098947525024 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 90.13256430625916 % 裏の手: 45.49036920070648 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 可能性が表の手: 85.6882393360138 % 裏の手: 10.46394556760788 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 87.13119626045227 % 裏の手: 11.574440449476242 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.64463472366333 % 裏の手: 11.751103401184082 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 28.528785705566406 % 裏の手: 9.91862490773201 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 30.59491515159607 % 裏の手: 12.87648230791092 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 81.2823235988617 % 裏の手: 10.467690974473953 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 75.6906270980835 % 裏の手: 13.84008377790451 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 可能性が表の手: 85.15656590461731 % 裏の手: 12.800492346286774 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 80.77952265739441 % 裏の手: 12.408778071403503 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 18.120859563350677 % 裏の手: 10.977064818143845 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.2895233631134 % 裏の手: 14.893700182437897 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 87.50287890434265 % 裏の手: 24.844670295715332 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 87.44604587554932 % 裏の手: 19.089503586292267 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 94.48020458221436 % 裏の手: 15.805846452713013 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 87.59351968765259 % 裏の手: 25.301751494407654 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 88.46526145935059 % 裏の手: 13.623170554637909 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 87.31617331504822 % 裏の手: 25.104093551635742 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.25304532051086 % 裏の手: 26.213151216506958 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 90.86526036262512 % 裏の手: 19.27834004163742 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 88.9157772064209 % 裏の手: 16.051085293293 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 58.910298347473145 % 裏の手: 22.105860710144043 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 27.71807312965393 % 裏の手: 16.926370561122894 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 47.00540006160736 % 裏の手: 16.818201541900635 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 26.39193832874298 % 裏の手: 16.158682107925415 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 73.37585091590881 % 裏の手: 16.51616096496582 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 64.79620337486267 % 裏の手: 14.150862395763397 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 69.93822455406189 % 裏の手: 15.513959527015686 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 63.81216049194336 % 裏の手: 12.930004298686981 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 35.72168052196503 % 裏の手: 21.356390416622162 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 42.27612614631653 % 裏の手: 13.437549769878387 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは100番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 28.740346431732178 % 裏の手: 8.197423815727234 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは101番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 39.4940972328186 % 裏の手: 12.331563234329224 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは102番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 31.353285908699036 % 裏の手: 11.205198615789413 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは103番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 可能性が表の手: 40.340620279312134 % 裏の手: 11.533812433481216 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは104番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 36.79581582546234 % 裏の手: 19.507627189159393 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは105番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 38.944536447525024 % 裏の手: 16.9976606965065 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは106番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 54.26986217498779 % 裏の手: 12.723734974861145 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは107番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 48.62380623817444 % 裏の手: 10.048708319664001 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは108番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 33.964163064956665 % 裏の手: 12.657594680786133 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは109番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 31.842494010925293 % 裏の手: 10.798406600952148 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは110番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 92.91252493858337 % 裏の手: 12.857943773269653 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは111番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 78.8486897945404 % 裏の手: 24.08013790845871 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは112番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 79.16601896286011 % 裏の手: 77.36920118331909 %なので認証します
#
# ここからは113番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 88.46479654312134 % 裏の手: 10.646375268697739 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは114番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 82.3343813419342 % 裏の手: 25.476866960525513 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは115番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 91.22845530509949 % 裏の手: 25.333359837532043 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは116番目の写真です
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 84.01649594306946 % 裏の手: 33.835017681121826 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは117番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 84.50472950935364 % 裏の手: 67.44898557662964 %なので認証します
#
# ここからは118番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.225337266922 % 裏の手: 22.215664386749268 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは119番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 78.17151546478271 % 裏の手: 51.42369270324707 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは120番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 44.063594937324524 % 裏の手: 8.755502849817276 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは121番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 69.29667592048645 % 裏の手: 9.861256182193756 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは122番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 48.80426526069641 % 裏の手: 8.751367032527924 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは123番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 40.37752151489258 % 裏の手: 7.979236543178558 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは124番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 60.320645570755005 % 裏の手: 10.584720969200134 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは125番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 可能性が表の手: 49.06191825866699 % 裏の手: 7.385749369859695 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは126番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 43.13884079456329 % 裏の手: 8.977074921131134 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは127番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 58.21537375450134 % 裏の手: 8.342278003692627 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは128番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 67.67021417617798 % 裏の手: 9.593836218118668 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは129番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 46.726298332214355 % 裏の手: 9.003011882305145 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは130番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 43.805131316185 % 裏の手: 20.326954126358032 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは131番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 69.3860650062561 % 裏の手: 18.457216024398804 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは132番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 86.50001287460327 % 裏の手: 21.30846232175827 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは133番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 66.22447371482849 % 裏の手: 25.97621977329254 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは134番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 74.0314245223999 % 裏の手: 19.177287817001343 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは135番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 74.73616600036621 % 裏の手: 10.546211153268814 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは136番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 58.03961157798767 % 裏の手: 10.841507464647293 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは137番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 67.93513298034668 % 裏の手: 17.42352843284607 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは138番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 57.045477628707886 % 裏の手: 10.037772357463837 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは139番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 61.38037443161011 % 裏の手: 22.224223613739014 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは140番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 59.85323190689087 % 裏の手: 12.767264246940613 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは141番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 63.74657154083252 % 裏の手: 12.087596207857132 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは142番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 47.98235893249512 % 裏の手: 12.541791796684265 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは143番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 65.8326506614685 % 裏の手: 14.182566106319427 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは144番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 49.898579716682434 % 裏の手: 13.094329833984375 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは145番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 37.66969442367554 % 裏の手: 12.635250389575958 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは146番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 48.56381118297577 % 裏の手: 14.215928316116333 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは147番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 71.77577018737793 % 裏の手: 13.716091215610504 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは148番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 50.14408826828003 % 裏の手: 11.419431865215302 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは149番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 36.67442798614502 % 裏の手: 11.66854202747345 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは150番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.5574254989624 % 裏の手: 21.628814935684204 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは151番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 82.58695602416992 % 裏の手: 9.915640205144882 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは152番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 71.15927934646606 % 裏の手: 10.814570635557175 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは153番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.38116359710693 % 裏の手: 10.720594972372055 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは154番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 97.22651243209839 % 裏の手: 12.101414799690247 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは155番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 89.0629529953003 % 裏の手: 12.498852610588074 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは156番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 89.41212296485901 % 裏の手: 21.743084490299225 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは157番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 67.52977967262268 % 裏の手: 10.146872699260712 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 でした
#
# ここからは158番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 65.62279462814331 % 裏の手: 22.57540076971054 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは159番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 91.82242751121521 % 裏の手: 23.792822659015656 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは160番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 44.77600455284119 % 裏の手: 39.9665504693985 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは161番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 60.08860468864441 % 裏の手: 33.33146274089813 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは162番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 69.5619285106659 % 裏の手: 25.47294795513153 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは163番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 68.17525625228882 % 裏の手: 22.36223816871643 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは164番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 75.79815983772278 % 裏の手: 41.28057360649109 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは165番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 82.2497308254242 % 裏の手: 46.527522802352905 %なので認証します
#
# ここからは166番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 72.64256477355957 % 裏の手: 16.808821260929108 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは167番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 62.637847661972046 % 裏の手: 17.557790875434875 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは168番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 71.84022665023804 % 裏の手: 17.54288822412491 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは169番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 90.49001336097717 % 裏の手: 15.42975902557373 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは170番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 28.14905345439911 % 裏の手: 10.581526905298233 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは171番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 32.75634050369263 % 裏の手: 10.346085578203201 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは172番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 35.457345843315125 % 裏の手: 10.189326107501984 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは173番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 23.94295036792755 % 裏の手: 10.07482185959816 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは174番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 24.71858561038971 % 裏の手: 10.30421033501625 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは175番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 42.680904269218445 % 裏の手: 9.84044149518013 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは176番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.33724761009216 % 裏の手: 9.743770211935043 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは177番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 39.861056208610535 % 裏の手: 10.339324176311493 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは178番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 28.177881240844727 % 裏の手: 7.576490938663483 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは179番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 24.697259068489075 % 裏の手: 10.737183690071106 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは180番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 67.56622791290283 % 裏の手: 18.271799385547638 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは181番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 61.60542964935303 % 裏の手: 23.38276505470276 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは182番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 可能性が表の手: 43.394893407821655 % 裏の手: 24.464768171310425 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは183番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 52.634382247924805 % 裏の手: 22.03286588191986 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは184番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 37.14582622051239 % 裏の手: 19.955436885356903 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは185番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 38.939741253852844 % 裏の手: 18.63533705472946 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは186番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 68.44959259033203 % 裏の手: 22.12320566177368 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは187番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 71.72173857688904 % 裏の手: 25.719597935676575 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは188番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 76.42157077789307 % 裏の手: 15.331146121025085 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは189番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 68.97084712982178 % 裏の手: 24.63284581899643 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは190番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 57.18790292739868 % 裏の手: 41.901108622550964 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは191番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 57.40668177604675 % 裏の手: 34.2974454164505 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは192番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 35.80162227153778 % 裏の手: 18.54180246591568 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは193番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 48.29186499118805 % 裏の手: 36.93973124027252 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは194番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 63.30392360687256 % 裏の手: 11.040910333395004 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは195番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 36.00672483444214 % 裏の手: 23.573115468025208 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは196番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 56.1636745929718 % 裏の手: 14.833517372608185 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは197番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 57.69103169441223 % 裏の手: 11.888869106769562 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは198番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 60.57775020599365 % 裏の手: 11.755073070526123 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは199番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 44.86547410488129 % 裏の手: 29.87898886203766 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
# [89.686119556427, 84.0026319026947, 96.17188572883606, 79.88094687461853, 88.57828378677368, 96.05751037597656, 90.13256430625916, 79.16601896286011, 84.50472950935364, 78.17151546478271, 82.2497308254242]
# [52.26408243179321, 51.78544521331787, 43.78758370876312, 65.62094688415527, 54.72198724746704, 49.93578791618347, 45.49036920070648, 77.36920118331909, 67.44898557662964, 51.42369270324707, 46.527522802352905]
# [31.9964736700058, 31.972679495811462, 35.59219837188721, 39.759451150894165, 29.445210099220276, 33.837202191352844, 27.25262939929962, 28.950214385986328, 39.95562791824341, 34.10504758358002, 33.62705111503601, 32.58487284183502, 39.64463472366333, 28.528785705566406, 30.59491515159607, 18.120859563350677, 27.71807312965393, 26.39193832874298, 35.72168052196503, 28.740346431732178, 39.4940972328186, 31.353285908699036, 36.79581582546234, 38.944536447525024, 33.964163064956665, 31.842494010925293, 37.66969442367554, 36.67442798614502, 28.14905345439911, 32.75634050369263, 35.457345843315125, 23.94295036792755, 24.71858561038971, 39.33724761009216, 39.861056208610535, 28.177881240844727, 24.697259068489075, 37.14582622051239, 38.939741253852844, 35.80162227153778, 36.00672483444214]
# [14.468125998973846, 25.408393144607544, 29.567694664001465, 16.890564560890198, 14.367461204528809, 11.525516211986542, 29.303893446922302, 18.540604412555695, 29.918202757835388, 25.817760825157166, 9.61218774318695, 13.19323480129242, 15.260852873325348, 10.535302013158798, 13.735054433345795, 13.723474740982056, 9.182682633399963, 13.917818665504456, 12.316490709781647, 15.545935928821564, 21.429455280303955, 11.637281626462936, 17.98054426908493, 22.00184166431427, 15.108685195446014, 16.83327555656433, 15.607266128063202, 23.793886601924896, 20.907263457775116, 17.336788773536682, 14.25275057554245, 27.576297521591187, 17.574071884155273, 23.13857227563858, 22.40491211414337, 21.445955336093903, 22.45831936597824, 30.66234588623047, 18.87807995080948, 27.392396330833435, 26.716327667236328, 17.990605533123016, 27.263712882995605, 19.53209489583969, 24.58507865667343, 27.075761556625366, 8.44854786992073, 35.62349081039429, 31.93250000476837, 20.650891959667206, 12.207993119955063, 18.43816637992859, 19.565248489379883, 19.05355304479599, 16.660606861114502, 18.707166612148285, 18.571476638317108, 17.75652766227722, 18.194863200187683, 15.077929198741913, 35.31932234764099, 39.30482864379883, 39.921098947525024, 10.46394556760788, 11.574440449476242, 11.751103401184082, 9.91862490773201, 12.87648230791092, 10.467690974473953, 13.84008377790451, 12.800492346286774, 12.408778071403503, 10.977064818143845, 14.893700182437897, 24.844670295715332, 19.089503586292267, 15.805846452713013, 25.301751494407654, 13.623170554637909, 25.104093551635742, 26.213151216506958, 19.27834004163742, 16.051085293293, 22.105860710144043, 16.926370561122894, 16.818201541900635, 16.158682107925415, 16.51616096496582, 14.150862395763397, 15.513959527015686, 12.930004298686981, 21.356390416622162, 13.437549769878387, 8.197423815727234, 12.331563234329224, 11.205198615789413, 11.533812433481216, 19.507627189159393, 16.9976606965065, 12.723734974861145, 10.048708319664001, 12.657594680786133, 10.798406600952148, 12.857943773269653, 24.08013790845871, 10.646375268697739, 25.476866960525513, 25.333359837532043, 33.835017681121826, 22.215664386749268, 8.755502849817276, 9.861256182193756, 8.751367032527924, 7.979236543178558, 10.584720969200134, 7.385749369859695, 8.977074921131134, 8.342278003692627, 9.593836218118668, 9.003011882305145, 20.326954126358032, 18.457216024398804, 21.30846232175827, 25.97621977329254, 19.177287817001343, 10.546211153268814, 10.841507464647293, 17.42352843284607, 10.037772357463837, 22.224223613739014, 12.767264246940613, 12.087596207857132, 12.541791796684265, 14.182566106319427, 13.094329833984375, 12.635250389575958, 14.215928316116333, 13.716091215610504, 11.419431865215302, 11.66854202747345, 21.628814935684204, 9.915640205144882, 10.814570635557175, 10.720594972372055, 12.101414799690247, 12.498852610588074, 21.743084490299225, 10.146872699260712, 22.57540076971054, 23.792822659015656, 39.9665504693985, 33.33146274089813, 25.47294795513153, 22.36223816871643, 41.28057360649109, 16.808821260929108, 17.557790875434875, 17.54288822412491, 15.42975902557373, 10.581526905298233, 10.346085578203201, 10.189326107501984, 10.07482185959816, 10.30421033501625, 9.84044149518013, 9.743770211935043, 10.339324176311493, 7.576490938663483, 10.737183690071106, 18.271799385547638, 23.38276505470276, 24.464768171310425, 22.03286588191986, 19.955436885356903, 18.63533705472946, 22.12320566177368, 25.719597935676575, 15.331146121025085, 24.63284581899643, 41.901108622550964, 34.2974454164505, 18.54180246591568, 36.93973124027252, 11.040910333395004, 23.573115468025208, 14.833517372608185, 11.888869106769562, 11.755073070526123, 29.87898886203766]
# -------------------------------------------------------------------
# 閾値以上で識別したテスト数22
# 閾値未満で識別したテスト数378
# 表の手だけで閾値未満で識別したテスト数41
# 裏の手だけで閾値未満で識別したテスト数189
# ================================================
# 本人拒否率94.5%
# 本人受入率5.5%
# 表の手で閾値未満の最大値は39.95562791824341
# 裏の手で閾値未満の最大値は41.901108622550964
# 表の平均値32.83585466262771
# 裏の平均値17.841275205845555
# 表の手で閾値以上の最小値は78.17151546478271
# 裏の手で閾値以上の最小値は43.78758370876312
# []
# 全体の他人受入率は1.6667%
# 10
# 0

# %%
#他人受入率評価用のプログラム (閾値を用いずに認証)
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/test/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/test/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128 
im_color = 3 
in_shape = (im_size, im_size, im_color)
#変更必要
nb_classes = 20
#配列の最大値
max_score = 0.0
batch = "256"

LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]

model_front = get_model(in_shape, nb_classes)
model_back  = get_model(in_shape, nb_classes)
#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')


#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 

#表の評価画像のチェック関数            
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size)) 
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "と一致しているので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "なので認証できません" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__ == '__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        #lの値はnumbersの個数によって変更の可否が決まる
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("RGB画像 " + str(im_size) + "px バッチサイズ" + str(batch))
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 70ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 58ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中ひろきさんの裏 なので認証できません
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 田中ひろきさんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 徳山さんの裏 なので認証できません
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 なので認証できません
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 高橋さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 徳山さんの裏 なので認証できません
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 田中たいきさんの裏 なので認証できません
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 中村さんの裏 なので認証できません
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 山口さんの裏 なので認証できません
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 と一致しているので認証します
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 島田さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 と一致しているので認証します
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 と一致しているので認証します
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 関根さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 なので認証できません
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 なので認証できません
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 と一致しているので認証します
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 と一致しているので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 と一致しているので認証します
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 渡邉さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 徳山さんの裏 なので認証できません
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
# [42.33314096927643, 49.715229868888855, 62.27647662162781, 32.77403116226196, 51.67693495750427, 39.52566683292389, 39.12360072135925, 9.666944295167923, 19.736596941947937, 16.278323531150818, 23.944027721881866, 7.564488798379898, 26.843106746673584, 12.492768466472626, 74.59912896156311, 61.34238839149475, 50.104206800460815, 82.14743137359619, 95.56227922439575, 64.9700403213501, 51.774436235427856, 53.254759311676025]
# [39.719438552856445, 82.16588497161865, 44.008445739746094, 25.88476538658142, 30.62862753868103, 51.848798990249634, 42.030683159828186, 54.81390953063965, 66.61524772644043, 22.420483827590942, 70.42180895805359, 41.91615879535675, 30.935943126678467, 76.18491053581238, 68.54992508888245, 42.74333119392395, 20.881640911102295, 65.51044583320618, 79.11690473556519, 63.33216428756714, 34.19197201728821, 95.92283368110657, 36.48654818534851, 80.49848079681396, 53.19729447364807, 64.67350125312805, 58.15826654434204, 85.58095693588257, 46.11329138278961, 92.11671948432922, 46.14750146865845, 77.86812782287598, 46.2115079164505, 87.841796875, 63.92441391944885, 82.65569806098938, 37.07720637321472, 47.53550589084625, 44.43005621433258, 83.48923325538635, 39.84316885471344, 48.47891330718994, 30.115073919296265, 82.7377438545227, 33.668252825737, 58.41740369796753, 15.950964391231537, 85.7367753982544, 41.113194823265076, 85.18716096878052, 34.662699699401855, 60.128092765808105, 39.18093740940094, 88.70823979377747, 66.40517115592957, 94.40120458602905, 34.407445788383484, 64.38549757003784, 24.022646248340607, 86.21494174003601, 32.82434046268463, 50.193047523498535, 25.94330608844757, 43.648672103881836, 27.009376883506775, 34.468117356300354, 16.327184438705444, 28.203070163726807, 28.987371921539307, 44.60724890232086, 52.92799472808838, 83.93078446388245, 38.692569732666016, 60.31252145767212, 28.584983944892883, 24.49541538953781, 41.4840966463089, 75.10643601417542, 40.8098965883255, 83.84153246879578, 43.10429096221924, 55.35377860069275, 41.13840162754059, 34.11675691604614, 43.561363220214844, 74.78771209716797, 37.81343400478363, 43.73134672641754, 56.15334510803223, 79.72838878631592, 32.15213716030121, 83.09422731399536, 32.23933279514313, 25.260326266288757, 47.83381223678589, 12.904942035675049, 37.69180178642273, 7.725560665130615, 20.92284858226776, 9.264066815376282, 47.73249626159668, 8.156052231788635, 39.903098344802856, 10.245166718959808, 32.476428151130676, 8.761946856975555, 35.94196140766144, 7.8171588480472565, 19.64506506919861, 9.185544401407242, 16.1174938082695, 13.310007750988007, 40.652650594711304, 12.228289991617203, 22.05328941345215, 8.451801538467407, 19.274845719337463, 14.871948957443237, 55.42626976966858, 10.225972533226013, 19.640038907527924, 21.54989391565323, 48.950207233428955, 11.696907132863998, 23.470738530158997, 9.53601822257042, 39.03098106384277, 13.206003606319427, 25.23004412651062, 10.851215571165085, 22.19228446483612, 10.388339310884476, 29.169511795043945, 8.824604004621506, 32.083660364151, 7.908523082733154, 26.192304491996765, 10.336307436227798, 27.484196424484253, 8.045218884944916, 30.57936429977417, 9.185463935136795, 21.7180073261261, 8.766122162342072, 20.884504914283752, 7.009381800889969, 48.90821576118469, 8.874034881591797, 50.81641674041748, 9.628573060035706, 37.0735228061676, 12.168599665164948, 49.404746294021606, 8.241921663284302, 46.99404835700989, 10.380031168460846, 43.24311017990112, 13.47668319940567, 44.80656385421753, 10.286498069763184, 35.866475105285645, 9.216135740280151, 33.410632610321045, 10.916899144649506, 47.75628447532654, 12.681812047958374, 28.743529319763184, 30.915677547454834, 44.71365511417389, 93.78702640533447, 71.67924046516418, 92.17135310173035, 49.910858273506165, 96.7305064201355, 45.641106367111206, 29.740548133850098, 53.71285080909729, 67.0499324798584]
# RGB画像 128px バッチサイズ256
# 他人受入に用いる個数22
# 閾値未満で識別したテスト数178
# ================================================
# 他人拒否率89.0%
# 他人受入率11.0%

# %%
#本人受入率評価用のプログラム(閾値を用いずに認証)
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
      "arai/right/omote",
      "ebato/right/omote",
      "hasegawa/right/omote",
      "higuchi/right/omote",
      "isii/right/omote",
      "kojima/right/omote",
      "nakamura/right/omote",
      "oono/right/omote",
      "sakai/right/omote",
      "sekine/right/omote",
      "shimada/right/omote",
      "shimizu/right/omote",
      "takahashi/right/omote",
      "tanakahiroki/right/omote",
      "tanakamiyu/right/omote",
      "tanakataiki/right/omote",
      "tokuyama/right/omote",
      "watanabe/right/omote",
      "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
      "arai/right/ura",
      "ebato/right/ura",
      "hasegawa/right/ura",
      "higuchi/right/ura",
      "isii/right/ura",
      "kojima/right/ura",
      "nakamura/right/ura",
      "oono/right/ura",
      "sakai/right/ura",
      "sekine/right/ura",
      "shimada/right/ura",
      "shimizu/right/ura",
      "takahashi/right/ura",
      "tanakahiroki/right/ura",
      "tanakamiyu/right/ura",
      "tanakataiki/right/ura",
      "tokuyama/right/ura",
      "watanabe/right/ura",
      "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023handstest/" + str(omote[k]) + "/rgb" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023handstest/" + str(ura[k]) + "/rgb" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 3 
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
batch = "256"

#学習した人のラベル
LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)
#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size))
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    else:
        pass
    idx = pre.argmax()
    per = (pre[idx] * 100)
    return(idx, per)
            

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "なので認証します")
        #上記条件を満たした時ラベルの中身が一致しているかどうかを確認
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS_Front[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Front[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS_Back[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Back[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "なので認証できません" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
        
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 71ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 江波戸の裏 なので認証できません
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 なので認証できません
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 大野さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは100番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは101番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは102番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは103番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは104番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは105番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは106番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは107番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは108番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは109番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは110番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは111番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは112番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは113番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは114番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは115番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは116番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは117番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは118番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは119番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは120番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは121番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは122番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは123番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは124番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは125番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは126番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは127番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは128番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは129番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは130番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは131番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは132番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは133番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは134番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは135番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは136番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 徳山さんの裏 なので認証できません
#
# ここからは137番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは138番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは139番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは140番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは141番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは142番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは143番目の写真です
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは144番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは145番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは146番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは147番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは148番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは149番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは150番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは151番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは152番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは153番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは154番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは155番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは156番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは157番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは158番目の写真です
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは159番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは160番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは161番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは162番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは163番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは164番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは165番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは166番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは167番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは168番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは169番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは170番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは171番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは172番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは173番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは174番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは175番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 渡邉さんの裏 なので認証できません
#
# ここからは176番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは177番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは178番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは179番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは180番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは181番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは182番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは183番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは184番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは185番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは186番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 渡邉さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは187番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは188番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは189番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは190番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは191番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは192番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは193番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは194番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは195番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは196番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは197番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは198番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは199番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
# [52.26324796676636, 14.468125998973846, 55.80375790596008, 25.408393144607544, 65.4345691204071, 29.567694664001465, 31.9964736700058, 16.890564560890198, 74.08157587051392, 14.367461204528809, 71.4996874332428, 29.303893446922302, 79.93721961975098, 18.540604412555695, 71.29729986190796, 29.918202757835388, 65.30008316040039, 25.817760825157166, 60.61587333679199, 9.61218774318695, 72.09872007369995, 13.19323480129242, 70.8163321018219, 15.260852873325348, 62.429314851760864, 10.535302013158798, 72.8137731552124, 13.735054433345795, 76.73750519752502, 13.723474740982056, 74.94209408760071, 9.182682633399963, 64.75030779838562, 13.917818665504456, 73.68191480636597, 12.316490709781647, 74.85242486000061, 15.545935928821564, 43.890419602394104, 21.429455280303955, 35.59219837188721, 11.637281626462936, 39.759451150894165, 17.98054426908493, 52.21567749977112, 22.00184166431427, 42.87298619747162, 16.83327555656433, 33.837202191352844, 15.607266128063202, 27.25262939929962, 23.793886601924896, 28.950214385986328, 20.907263457775116, 48.286694288253784, 17.336788773536682, 60.251837968826294, 14.25275057554245, 59.797126054763794, 27.576297521591187, 63.08615803718567, 17.574071884155273, 64.7052526473999, 23.13857227563858, 67.56069660186768, 22.40491211414337, 67.09471344947815, 21.445955336093903, 66.79796576499939, 22.45831936597824, 76.8183171749115, 30.66234588623047, 70.9635078907013, 18.87807995080948, 68.6427116394043, 27.392396330833435, 39.95562791824341, 26.716327667236328, 44.118356704711914, 27.263712882995605, 44.70559060573578, 19.53209489583969, 61.149805784225464, 24.58507865667343, 33.62705111503601, 27.075761556625366, 64.59696292877197, 35.62349081039429, 63.456594944000244, 31.93250000476837, 46.08961641788483, 20.650891959667206, 75.89200735092163, 12.207993119955063, 71.24409675598145, 18.43816637992859, 71.66325449943542, 19.565248489379883, 66.54092669487, 19.05355304479599, 69.85172033309937, 16.660606861114502, 76.57362818717957, 18.707166612148285, 70.8694338798523, 18.571476638317108, 88.58869671821594, 17.75652766227722, 77.06138491630554, 18.194863200187683, 79.74211573600769, 15.077929198741913, 76.78728699684143, 35.31932234764099, 89.686119556427, 52.26408243179321, 84.0026319026947, 51.78544521331787, 96.17188572883606, 43.78758370876312, 79.88094687461853, 65.62094688415527, 88.57828378677368, 54.72198724746704, 96.05751037597656, 49.93578791618347, 72.43601679801941, 39.30482864379883, 73.44082593917847, 39.921098947525024, 90.13256430625916, 45.49036920070648, 85.6882393360138, 10.46394556760788, 87.13119626045227, 11.574440449476242, 39.64463472366333, 11.751103401184082, 30.59491515159607, 12.87648230791092, 81.2823235988617, 10.467690974473953, 75.6906270980835, 13.84008377790451, 85.15656590461731, 12.800492346286774, 80.77952265739441, 12.408778071403503, 94.2895233631134, 14.893700182437897, 87.50287890434265, 24.844670295715332, 87.44604587554932, 19.089503586292267, 94.48020458221436, 15.805846452713013, 87.59351968765259, 25.301751494407654, 88.46526145935059, 13.623170554637909, 87.31617331504822, 25.104093551635742, 94.25304532051086, 26.213151216506958, 90.86526036262512, 19.27834004163742, 88.9157772064209, 16.051085293293, 58.910298347473145, 22.105860710144043, 47.00540006160736, 16.818201541900635, 73.37585091590881, 16.51616096496582, 64.79620337486267, 14.150862395763397, 69.93822455406189, 15.513959527015686, 63.81216049194336, 12.930004298686981, 35.72168052196503, 21.356390416622162, 42.27612614631653, 13.437549769878387, 28.740346431732178, 8.197423815727234, 39.4940972328186, 12.331563234329224, 31.353285908699036, 11.205198615789413, 40.340620279312134, 11.533812433481216, 36.79581582546234, 19.507627189159393, 38.944536447525024, 16.9976606965065, 54.26986217498779, 12.723734974861145, 48.62380623817444, 10.048708319664001, 33.964163064956665, 12.657594680786133, 31.842494010925293, 10.798406600952148, 92.91252493858337, 12.857943773269653, 78.8486897945404, 24.08013 ...
# [31.972679495811462, 11.525516211986542, 29.445210099220276, 15.108685195446014, 34.10504758358002, 17.990605533123016, 32.58487284183502, 8.44854786992073, 28.528785705566406, 9.91862490773201, 18.120859563350677, 10.977064818143845, 27.71807312965393, 16.926370561122894, 26.39193832874298, 16.158682107925415, 58.03961157798767, 10.841507464647293, 82.58695602416992, 9.915640205144882, 71.15927934646606, 10.814570635557175, 96.38116359710693, 10.720594972372055, 67.52977967262268, 10.146872699260712, 42.680904269218445, 9.84044149518013, 68.44959259033203, 22.12320566177368]
# -------------------------------------------------------------------
# 閾値以上で識別したテスト数370
# 閾値未満で識別したテスト数30
# ================================================
# 本人拒否率7.5%
# 本人受入率92.5%
# []
# 全体の他人受入率は3.6667%
