# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num20FrontRGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/omote", 0)
    glob_files("D:/過去の研究データ/2023hands/arai/right/omote", 1)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/omote", 2)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/omote", 3)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/omote", 4)
    glob_files("D:/過去の研究データ/2023hands/isii/right/omote", 5)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/omote", 6)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/omote", 7)
    glob_files("D:/過去の研究データ/2023hands/oono/right/omote", 8)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/omote", 9)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/omote", 10)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/omote", 11)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/omote", 12)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/omote", 13)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/omote", 14)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/omote", 15)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/omote", 16)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/omote", 17)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/omote", 18)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/omote", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__ == '__main__':
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
#写真データ読み込み
photos=np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num20FrontRGB-128pix.npz')
x=photos['x']
y=photos['y']
#開始インデックス
idx=7500
#pyplotで出力
plt.figure(figsize=(10,10))
plt.axis("off")


for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis("off")
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])

#--------------------画像1枚をピックアップして保存する-----------------------------
#plt.savefig('./extract.jpg')
plt.show()

# %%
#表の手と裏の手を別々に学習するプログラム
import numpy as np
from PIL import Image
import cv2
import os,glob,random
import matplotlib.pyplot as plt
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num20BackRGB-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023hands/aizawa/right/ura", 0)
    glob_files("D:/過去の研究データ/2023hands/arai/right/ura", 1)
    glob_files("D:/過去の研究データ/2023hands/ebato/right/ura", 2)
    glob_files("D:/過去の研究データ/2023hands/hasegawa/right/ura", 3)
    glob_files("D:/過去の研究データ/2023hands/higuchi/right/ura", 4)
    glob_files("D:/過去の研究データ/2023hands/isii/right/ura", 5)
    glob_files("D:/過去の研究データ/2023hands/kojima/right/ura", 6)
    glob_files("D:/過去の研究データ/2023hands/nakamura/right/ura", 7)
    glob_files("D:/過去の研究データ/2023hands/oono/right/ura", 8)
    glob_files("D:/過去の研究データ/2023hands/sakai/right/ura", 9)
    glob_files("D:/過去の研究データ/2023hands/sekine/right/ura", 10)
    glob_files("D:/過去の研究データ/2023hands/shimada/right/ura", 11)
    glob_files("D:/過去の研究データ/2023hands/shimizu/right/ura", 12)
    glob_files("D:/過去の研究データ/2023hands/takahashi/right/ura", 13)
    glob_files("D:/過去の研究データ/2023hands/tanakahiroki/right/ura", 14)
    glob_files("D:/過去の研究データ/2023hands/tanakamiyu/right/ura", 15)
    glob_files("D:/過去の研究データ/2023hands/tanakataiki/right/ura", 16)
    glob_files("D:/過去の研究データ/2023hands/tokuyama/right/ura", 17)
    glob_files("D:/過去の研究データ/2023hands/watanabe/right/ura", 18)
    glob_files("D:/過去の研究データ/2023hands/yamaguchi/right/ura", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1
        img = cv2.imread(f) 
        #解像度の変更  
        result_img = cv2.resize(img, (photo_size, photo_size)) 
        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__ == '__main__':
    main()

# %%
# %%time
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    model.summary()
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

# 変更必要
im_size = 128 
im_color = 3
in_shape = (im_size, im_size, im_color)
nb_classes = 20
hands = "Back"
batch = 256

photos = np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/2023Num20' + hands + 'RGB-' + str(im_size) + 'pix.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_size, im_size, im_color)
x = x.astype('float32') / 255
y = keras.utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size = 0.9)

model = get_model(in_shape, nb_classes)


hist = model.fit(x_train, y_train,
          batch_size = batch, 
          epochs = 20,
          verbose = 1,
          validation_data = (x_test, y_test))

score = model.evaluate(x_test, y_test, verbose = 1)
print('正解率=', score[1], 'loss=', score[0])


plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

model.save_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20' + hands + 'RGB-' + str(im_size) + 'pixBatch' + str(batch) + '.hdf5')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 126, 126, 32)      896
#
#  conv2d_29 (Conv2D)          (None, 124, 124, 32)      9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 62, 62, 32)        0
#
#  conv2d_30 (Conv2D)          (None, 60, 60, 64)        18496
#
#  conv2d_31 (Conv2D)          (None, 58, 58, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 29, 29, 64)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 29, 29, 64)        0
#
#  flatten_7 (Flatten)         (None, 53824)             0
#
#  dense_14 (Dense)            (None, 512)               27558400
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_15 (Dense)            (None, 20)                10260
#
# =================================================================
# Total params: 27,634,228
# Trainable params: 27,634,228
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 27/27 [==============================] - 138s 5s/step - loss: 2.6548 - accuracy: 0.2958 - val_loss: 0.5774 - val_accuracy: 0.9241
# Epoch 2/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.1750 - accuracy: 0.9513 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 3/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.0697 - val_accuracy: 0.9627
# Epoch 4/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.1101 - accuracy: 0.9782 - val_loss: 1.7224e-04 - val_accuracy: 1.0000
# Epoch 5/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.8674 - accuracy: 0.9568 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 6/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 2.3089e-05 - val_accuracy: 1.0000
# Epoch 7/20
# 27/27 [==============================] - 130s 5s/step - loss: 9.0866e-04 - accuracy: 0.9999 - val_loss: 5.0388e-06 - val_accuracy: 1.0000
# Epoch 8/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.2960 - accuracy: 0.9525 - val_loss: 1.4726e-04 - val_accuracy: 1.0000
# Epoch 9/20
# 27/27 [==============================] - 129s 5s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.1829e-06 - val_accuracy: 1.0000
# Epoch 10/20
# 27/27 [==============================] - 129s 5s/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 2.4139e-05 - val_accuracy: 1.0000
# Epoch 11/20
# 27/27 [==============================] - 129s 5s/step - loss: 0.2966 - accuracy: 0.9779 - val_loss: 9.1755e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 27/27 [==============================] - 129s 5s/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 2.5488e-05 - val_accuracy: 1.0000
# Epoch 13/20
# 27/27 [==============================] - 129s 5s/step - loss: 4.2728e-04 - accuracy: 1.0000 - val_loss: 3.7195e-06 - val_accuracy: 1.0000
# Epoch 14/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.2981 - accuracy: 0.9941 - val_loss: 0.0257 - val_accuracy: 0.9920
# Epoch 15/20
# 27/27 [==============================] - 131s 5s/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 2.2856e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 27/27 [==============================] - 131s 5s/step - loss: 5.0444e-04 - accuracy: 0.9999 - val_loss: 9.1830e-06 - val_accuracy: 1.0000
# Epoch 17/20
# 27/27 [==============================] - 130s 5s/step - loss: 0.0770 - accuracy: 0.9932 - val_loss: 3.5604e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 27/27 [==============================] - 127s 5s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 2.7102e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 27/27 [==============================] - 123s 5s/step - loss: 6.1095e-04 - accuracy: 0.9997 - val_loss: 1.4957e-06 - val_accuracy: 1.0000
# Epoch 20/20
# 27/27 [==============================] - 124s 5s/step - loss: 7.4569e-05 - accuracy: 1.0000 - val_loss: 4.5771e-07 - val_accuracy: 1.0000
# 24/24 [==============================] - 2s 98ms/step - loss: 4.5771e-07 - accuracy: 1.0000
# 正解率= 1.0 loss= 4.577115646497987e-07
# Wall time: 43min 14s

# %%
#他人受入率評価用のプログラム 
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#閾値の設定⇒変更必要
thresh = 99.9

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/test/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/test/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128 
im_color = 3 
in_shape = (im_size, im_size, im_color)
#変更必要
nb_classes = 20
#配列の最大値
max_score = 0.0
batch = "256"

LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]

model_front = get_model(in_shape, nb_classes)
model_back  = get_model(in_shape, nb_classes)
#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')


#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 

#表の評価画像のチェック関数            
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size)) 
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < thresh and ("/omote" in path): 
        omoteNotPercent.append(per)
    elif per < thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= thresh and per_ura >= thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__ == '__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        #lの値はnumbersの個数によって変更の可否が決まる
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    omotenotpass = len(omoteNotPercent) / 100
    omotepass = (100 - len(omoteNotPercent)) / 100
    uranotpass = len(uraNotPercent) / 100
    urapass = (100 - len(uraNotPercent)) / 100
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
    print("表の手だけで未学習の手を閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    print("表の手だけで未学習の手を閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    print("裏の手だけで未学習の手を閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    print("裏の手だけで未学習の手を閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    print("閾値以上の最大値は" + str(max_score)) 
    try:
        print("閾値以上の最小値は" + str(min(passpercent))) 
    except:
        pass
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 可能性が表の手: 98.61806035041809 % 裏の手: 82.80380368232727 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 80.42367696762085 % 裏の手: 89.47999477386475 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 66.18205308914185 % 裏の手: 99.80803728103638 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 94.02953386306763 % 裏の手: 99.98849630355835 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 87.7102255821228 % 裏の手: 75.98633766174316 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 清水さんの裏 でした
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 62.885600328445435 % 裏の手: 81.04878067970276 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.1138756275177 % 裏の手: 99.89452958106995 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 88.52971196174622 % 裏の手: 97.64935374259949 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 関根さんの裏 でした
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 97.1811830997467 % 裏の手: 86.26566529273987 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 93.97067427635193 % 裏の手: 95.15998959541321 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 田中ひろきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 67.54636764526367 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 56.23560547828674 % 裏の手: 99.99279975891113 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 90.54954648017883 % 裏の手: 99.99957084655762 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.10409331321716 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.04121220111847 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 39.17612433433533 % 裏の手: 77.5303840637207 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 42.098987102508545 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 34.1243177652359 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 66.00366830825806 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 47.480958700180054 % 裏の手: 99.99997615814209 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 高橋さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 95.69341540336609 % 裏の手: 99.99855756759644 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 79.96937036514282 % 裏の手: 98.32487106323242 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 93.78166794776917 % 裏の手: 99.99686479568481 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 89.98116850852966 % 裏の手: 90.40694236755371 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 54.91915941238403 % 裏の手: 98.38062524795532 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 島田さんの裏 でした
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 66.02208018302917 % 裏の手: 96.49619460105896 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 76.5367329120636 % 裏の手: 74.63344931602478 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 58.67828130722046 % 裏の手: 93.35302114486694 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 97.88092970848083 % 裏の手: 49.37176704406738 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 88.2906436920166 % 裏の手: 98.01837801933289 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 77.00077891349792 % 裏の手: 99.84439015388489 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 79.15920615196228 % 裏の手: 97.03910946846008 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 78.7036657333374 % 裏の手: 94.72475051879883 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 52.74078845977783 % 裏の手: 94.55596208572388 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 46.429288387298584 % 裏の手: 99.21257495880127 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.39943647384644 % 裏の手: 88.94214630126953 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 81.19633793830872 % 裏の手: 99.8913049697876 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 76.3227641582489 % 裏の手: 99.84446167945862 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 40.35358428955078 % 裏の手: 61.76772713661194 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 64.02485370635986 % 裏の手: 99.9146580696106 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 徳山さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 74.37628507614136 % 裏の手: 91.52805209159851 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 新井さんの裏 でした
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.285489320755 % 裏の手: 99.90822076797485 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 新井さんの裏 でした
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 81.06107115745544 % 裏の手: 99.98506307601929 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 関根さんの裏 でした
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 77.13412046432495 % 裏の手: 99.99923706054688 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 38.44834268093109 % 裏の手: 99.98051524162292 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 中村さんの裏 でした
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 55.39296865463257 % 裏の手: 98.13499450683594 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 中村さんの裏 でした
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 91.27453565597534 % 裏の手: 99.99706745147705 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 73.95557761192322 % 裏の手: 91.98781251907349 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 中村さんの裏 でした
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 42.03304052352905 % 裏の手: 64.03712630271912 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 関根さんの裏 でした
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.72526431083679 % 裏の手: 99.97066855430603 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 徳山さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 86.66187524795532 % 裏の手: 99.93475079536438 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 山口さんの裏 でした
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.53742623329163 % 裏の手: 78.66202592849731 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 中村さんの裏 でした
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 31.32772147655487 % 裏の手: 99.48415160179138 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 45.50041854381561 % 裏の手: 93.66645216941833 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 山口さんの裏 でした
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 52.2178053855896 % 裏の手: 58.10154676437378 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 中村さんの裏 でした
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.3272590637207 % 裏の手: 88.1482720375061 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 山口さんの裏 でした
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 90.92109203338623 % 裏の手: 55.620551109313965 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 山口さんの裏 でした
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 90.32858610153198 % 裏の手: 92.39522814750671 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 山口さんの裏 でした
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 70.9713876247406 % 裏の手: 55.68234920501709 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 山口さんの裏 でした
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 66.18127226829529 % 裏の手: 70.63437104225159 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 中村さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 可能性が表の手: 61.921489238739014 % 裏の手: 96.47568464279175 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 99.37361478805542 % 裏の手: 52.26817727088928 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 新井さんの裏 でした
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 46.104586124420166 % 裏の手: 95.93631625175476 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 64.62137699127197 % 裏の手: 46.31681144237518 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 中村さんの裏 でした
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.24055600166321 % 裏の手: 94.62689757347107 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 新井さんの裏 でした
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 35.619741678237915 % 裏の手: 99.97137188911438 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 86.42659783363342 % 裏の手: 98.2378900051117 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 49.69036281108856 % 裏の手: 83.63269567489624 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 中村さんの裏 でした
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 可能性が表の手: 42.18676686286926 % 裏の手: 95.02511620521545 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 45.72751820087433 % 裏の手: 95.42640447616577 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 72.86251187324524 % 裏の手: 92.25080013275146 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 94.7178840637207 % 裏の手: 99.8345136642456 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.30274176597595 % 裏の手: 69.4014310836792 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 76.58488154411316 % 裏の手: 81.27665519714355 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 島田さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 97.47511744499207 % 裏の手: 50.09927749633789 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 90.51079154014587 % 裏の手: 75.40578246116638 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.7471878528595 % 裏の手: 97.34062552452087 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 島田さんの裏 でした
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.9525694847107 % 裏の手: 44.28325593471527 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.78687262535095 % 裏の手: 58.118629455566406 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.76294326782227 % 裏の手: 98.34747910499573 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 89.89697098731995 % 裏の手: 99.9438464641571 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 88.34651112556458 % 裏の手: 99.42753911018372 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 42.787495255470276 % 裏の手: 84.40200686454773 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 85.10698080062866 % 裏の手: 99.98194575309753 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 72.47143387794495 % 裏の手: 97.48725891113281 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 89.37186002731323 % 裏の手: 57.11132287979126 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.63537645339966 % 裏の手: 99.99251365661621 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 65.35757780075073 % 裏の手: 99.77276921272278 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 70.72350978851318 % 裏の手: 83.32967758178711 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 可能性が表の手: 91.38879179954529 % 裏の手: 96.57955169677734 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中みゆさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 46.739399433135986 % 裏の手: 99.99967813491821 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 55.64694404602051 % 裏の手: 99.99855756759644 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.98418092727661 % 裏の手: 99.99101161956787 %なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.82617497444153 % 裏の手: 99.87815022468567 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 87.1548593044281 % 裏の手: 99.99912977218628 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 88.77590894699097 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.72042441368103 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 99.89559650421143 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 63.50051164627075 % 裏の手: 99.99957084655762 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 46.244433522224426 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 高橋さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
# [99.98418092727661, 99.99101161956787]
# [98.61806035041809, 82.80380368232727, 80.42367696762085, 89.47999477386475, 66.18205308914185, 99.80803728103638, 94.02953386306763, 99.98849630355835, 87.7102255821228, 75.98633766174316, 62.885600328445435, 81.04878067970276, 99.1138756275177, 99.89452958106995, 88.52971196174622, 97.64935374259949, 97.1811830997467, 86.26566529273987, 93.97067427635193, 95.15998959541321, 67.54636764526367, 99.99998807907104, 56.23560547828674, 99.99279975891113, 90.54954648017883, 99.99957084655762, 94.10409331321716, 100.0, 39.04121220111847, 99.99998807907104, 39.17612433433533, 77.5303840637207, 42.098987102508545, 100.0, 34.1243177652359, 99.99998807907104, 66.00366830825806, 100.0, 47.480958700180054, 99.99997615814209, 95.69341540336609, 99.99855756759644, 79.96937036514282, 98.32487106323242, 93.78166794776917, 99.99686479568481, 89.98116850852966, 90.40694236755371, 54.91915941238403, 98.38062524795532, 66.02208018302917, 96.49619460105896, 76.5367329120636, 74.63344931602478, 58.67828130722046, 93.35302114486694, 97.88092970848083, 49.37176704406738, 88.2906436920166, 98.01837801933289, 77.00077891349792, 99.84439015388489, 79.15920615196228, 97.03910946846008, 78.7036657333374, 94.72475051879883, 52.74078845977783, 94.55596208572388, 46.429288387298584, 99.21257495880127, 98.39943647384644, 88.94214630126953, 81.19633793830872, 99.8913049697876, 76.3227641582489, 99.84446167945862, 40.35358428955078, 61.76772713661194, 64.02485370635986, 99.9146580696106, 74.37628507614136, 91.52805209159851, 99.285489320755, 99.90822076797485, 81.06107115745544, 99.98506307601929, 77.13412046432495, 99.99923706054688, 38.44834268093109, 99.98051524162292, 55.39296865463257, 98.13499450683594, 91.27453565597534, 99.99706745147705, 73.95557761192322, 91.98781251907349, 42.03304052352905, 64.03712630271912, 99.72526431083679, 99.97066855430603, 86.66187524795532, 99.93475079536438, 99.53742623329163, 78.66202592849731, 31.32772147655487, 99.48415160179138, 45.50041854381561, 93.66645216941833, 52.2178053855896, 58.10154676437378, 94.3272590637207, 88.1482720375061, 90.92109203338623, 55.620551109313965, 90.32858610153198, 92.39522814750671, 70.9713876247406, 55.68234920501709, 66.18127226829529, 70.63437104225159, 61.921489238739014, 96.47568464279175, 99.37361478805542, 52.26817727088928, 46.104586124420166, 95.93631625175476, 64.62137699127197, 46.31681144237518, 90.24055600166321, 94.62689757347107, 35.619741678237915, 99.97137188911438, 86.42659783363342, 98.2378900051117, 49.69036281108856, 83.63269567489624, 42.18676686286926, 95.02511620521545, 45.72751820087433, 95.42640447616577, 72.86251187324524, 92.25080013275146, 94.7178840637207, 99.8345136642456, 96.30274176597595, 69.4014310836792, 76.58488154411316, 81.27665519714355, 97.47511744499207, 50.09927749633789, 90.51079154014587, 75.40578246116638, 98.7471878528595, 97.34062552452087, 96.9525694847107, 44.28325593471527, 98.78687262535095, 58.118629455566406, 96.76294326782227, 98.34747910499573, 89.89697098731995, 99.9438464641571, 88.34651112556458, 99.42753911018372, 42.787495255470276, 84.40200686454773, 85.10698080062866, 99.98194575309753, 72.47143387794495, 97.48725891113281, 89.37186002731323, 57.11132287979126, 97.63537645339966, 99.99251365661621, 65.35757780075073, 99.77276921272278, 70.72350978851318, 83.32967758178711, 91.38879179954529, 96.57955169677734, 46.739399433135986, 99.99967813491821, 55.64694404602051, 99.99855756759644, 99.82617497444153, 99.87815022468567, 87.1548593044281, 99.99912977218628, 88.77590894699097, 99.99998807907104, 99.72042441368103, 100.0, 99.89559650421143, 99.99998807907104, 63.50051164627075, 99.99957084655762, 46.244433522224426, 100.0]
# 他人受入に用いる個数2
# 閾値未満で識別したテスト数198
# 表の手だけで閾値未満で識別したテスト数99
# 裏の手だけで閾値未満で識別したテスト数67
# ================================================
# 他人拒否率99.0%
# 他人受入率1.0%
# 表の手だけで未学習の手を閾値未満で識別した割合99.0%
# 表の手だけで未学習の手を閾値以上で識別した割合1.0%
# 裏の手だけで未学習の手を閾値未満で識別した割合67.0%
# 裏の手だけで未学習の手を閾値以上で識別した割合33.0%
# 閾値以上の最大値は99.99101161956787
# 閾値以上の最小値は99.98418092727661

# %%
#本人受入率評価用のプログラム
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
      "arai/right/omote",
      "ebato/right/omote",
      "hasegawa/right/omote",
      "higuchi/right/omote",
      "isii/right/omote",
      "kojima/right/omote",
      "nakamura/right/omote",
      "oono/right/omote",
      "sakai/right/omote",
      "sekine/right/omote",
      "shimada/right/omote",
      "shimizu/right/omote",
      "takahashi/right/omote",
      "tanakahiroki/right/omote",
      "tanakamiyu/right/omote",
      "tanakataiki/right/omote",
      "tokuyama/right/omote",
      "watanabe/right/omote",
      "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
      "arai/right/ura",
      "ebato/right/ura",
      "hasegawa/right/ura",
      "higuchi/right/ura",
      "isii/right/ura",
      "kojima/right/ura",
      "nakamura/right/ura",
      "oono/right/ura",
      "sakai/right/ura",
      "sekine/right/ura",
      "shimada/right/ura",
      "shimizu/right/ura",
      "takahashi/right/ura",
      "tanakahiroki/right/ura",
      "tanakamiyu/right/ura",
      "tanakataiki/right/ura",
      "tokuyama/right/ura",
      "watanabe/right/ura",
      "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023handstest/" + str(omote[k]) + "/rgb" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023handstest/" + str(ura[k]) + "/rgb" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 3 
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
#閾値の設定
thresh = 99.99999
batch = "256"

#学習した人のラベル
LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)
#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackRGB-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = Image.open(path)
    #画像のリサイズ
    result_img = img.resize((im_size, im_size))
    # plt.imshow(result_img)
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    else:
        pass
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < thresh and ("/omote" in path):
        omoteNotPercent.append(per)
    elif per < thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return(idx, per)
            

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= thresh and per_ura >= thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")
        #上記条件を満たした時ラベルの中身が一致しているかどうかを確認
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS_Front[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Front[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS_Back[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Back[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #check_photo_strに接続
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
        
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    omotenotpass = len(omoteNotPercent) / 200
    omotepass = (200 - len(omoteNotPercent)) / 200
    uranotpass = len(uraNotPercent) / 200
    urapass = (200 - len(uraNotPercent)) / 200
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    print("表の手だけを閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    print("表の手だけを閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    print("裏の手だけを閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    print("裏の手だけを閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    print("閾値以上の最大値は" + str(max_score))
    try:
        print("閾値以上の最小値は" + str(min(passpercent)))
    except:
        pass
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
    #他人受入率の算出時に受け入れてしまった個数
    print(FAR)
    #学習済みの人の手の中で他人を受入れてしまった人の個数
    print(len(notIncludeLABEL))
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 72ms/step
# 可能性が表の手: 98.0093240737915 % 裏の手: 99.73028898239136 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.35587048530579 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.83266091346741 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.13905954360962 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.2186427116394 % 裏の手: 99.99997615814209 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 60.8864963054657 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.31425547599792 % 裏の手: 99.99514818191528 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.7544298171997 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.8980770111084 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.94315695762634 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 83.52978229522705 % 裏の手: 99.99922513961792 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 86.76815629005432 % 裏の手: 99.99948740005493 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.57281017303467 % 裏の手: 99.9998927116394 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.9633538722992 % 裏の手: 99.99922513961792 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 78.66669297218323 % 裏の手: 99.99409914016724 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 86.98002696037292 % 裏の手: 99.99994039535522 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 92.97783374786377 % 裏の手: 99.99971389770508 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.3215479850769 % 裏の手: 99.99369382858276 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 93.75462532043457 % 裏の手: 99.99994039535522 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 90.93403816223145 % 裏の手: 99.99992847442627 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 新井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.57069754600525 % 裏の手: 99.7465968132019 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.68260526657104 % 裏の手: 99.34648871421814 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.81154203414917 % 裏の手: 99.65066313743591 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 99.34725761413574 % 裏の手: 92.3269510269165 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.74752068519592 % 裏の手: 99.9887466430664 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.88707900047302 % 裏の手: 99.99600648880005 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 99.3636965751648 % 裏の手: 99.56902861595154 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.80006909370422 % 裏の手: 95.01668810844421 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.41902160644531 % 裏の手: 94.10178065299988 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.58299994468689 % 裏の手: 99.36196208000183 %なので認証できません
# 認証の結果は表の手: 江波戸の表  裏の手: 江波戸の裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 66.23193025588989 % 裏の手: 99.9439537525177 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.28767371177673 % 裏の手: 99.99991655349731 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.7562894821167 % 裏の手: 99.99985694885254 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.05258417129517 % 裏の手: 99.99992847442627 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 92.38966107368469 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 95.84619998931885 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 96.86084985733032 % 裏の手: 99.99983310699463 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.45173954963684 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.79735708236694 % 裏の手: 99.99939203262329 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 98.24391603469849 % 裏の手: 99.99988079071045 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 長谷川さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.3806083202362 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.17477059364319 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.4312355518341 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.69824838638306 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.56641793251038 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.94761347770691 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.81005787849426 % 裏の手: 99.90039467811584 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.83202815055847 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.77012276649475 % 裏の手: 99.99985694885254 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.69207835197449 % 裏の手: 99.99992847442627 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 可能性が表の手: 95.15829086303711 % 裏の手: 99.98258948326111 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 83.11919569969177 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 85.40249466896057 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 90.97825288772583 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 90.90001583099365 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.42020463943481 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 93.89467239379883 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.74864721298218 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.32378625869751 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 93.78606081008911 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.98817443847656 % 裏の手: 99.99995231628418 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.99645948410034 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.99854564666748 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.99978542327881 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.99130964279175 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99498128890991 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99970197677612 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.98775720596313 % 裏の手: 99.99949932098389 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.99511241912842 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.99949932098389 % 裏の手: 99.99988079071045 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 小島さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.4076132774353 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.91582727432251 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.6055076122284 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 86.39832735061646 % 裏の手: 99.99997615814209 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.8056092262268 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.28991794586182 % 裏の手: 99.99929666519165 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.14355874061584 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.75252747535706 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.75361824035645 % 裏の手: 99.9998927116394 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 可能性が表の手: 74.08103346824646 % 裏の手: 99.99943971633911 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.00982975959778 % 裏の手: 99.99983310699463 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.997563123703 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 99.18096661567688 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.96860718727112 % 裏の手: 99.99983310699463 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.18226599693298 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.31868314743042 % 裏の手: 99.99837875366211 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.4950532913208 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.07254576683044 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 96.72526717185974 % 裏の手: 99.99995231628418 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.73691201210022 % 裏の手: 99.99817609786987 %なので認証できません
# 認証の結果は表の手: 大野さんの表  裏の手: 大野さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 80.77658414840698 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 98.26810956001282 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 94.45129632949829 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.50640892982483 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.81335783004761 % 裏の手: 99.99967813491821 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.67053198814392 % 裏の手: 99.99951124191284 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.52181363105774 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.82656335830688 % 裏の手: 99.99104738235474 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 73.44976663589478 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 82.17095732688904 % 裏の手: 99.98353719711304 %なので認証できません
# 認証の結果は表の手: 坂井さんの表  裏の手: 坂井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは100番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 88.53944540023804 % 裏の手: 99.85759258270264 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは101番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.21117115020752 % 裏の手: 99.46078062057495 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは102番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.24794721603394 % 裏の手: 99.99474287033081 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは103番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.65282082557678 % 裏の手: 99.86618757247925 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは104番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.45355153083801 % 裏の手: 99.99713897705078 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは105番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 97.24774360656738 % 裏の手: 99.99295473098755 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは106番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.77278113365173 % 裏の手: 96.69472575187683 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは107番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.86355900764465 % 裏の手: 82.92838931083679 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは108番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.91693186759949 % 裏の手: 86.7638111114502 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
#
# ここからは109番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.143869638443 % 裏の手: 99.98716115951538 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 関根さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは110番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 93.02595257759094 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは111番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 96.8599021434784 % 裏の手: 99.99995231628418 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは112番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.49209094047546 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは113番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 可能性が表の手: 97.41893410682678 % 裏の手: 99.9991774559021 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは114番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.10208082199097 % 裏の手: 99.99994039535522 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは115番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 96.6289758682251 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは116番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 95.06308436393738 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは117番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.30374026298523 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは118番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.94600415229797 % 裏の手: 99.99991655349731 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
#
# ここからは119番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 91.37400388717651 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは120番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.8285858631134 % 裏の手: 99.94613528251648 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは121番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.9493956565857 % 裏の手: 99.99979734420776 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは122番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.88555908203125 % 裏の手: 99.99921321868896 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは123番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 93.66573095321655 % 裏の手: 99.99948740005493 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは124番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.61826205253601 % 裏の手: 99.99974966049194 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは125番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.3055591583252 % 裏の手: 99.94015693664551 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは126番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 91.01943969726562 % 裏の手: 99.91021156311035 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは127番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 98.07682633399963 % 裏の手: 99.98121857643127 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは128番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 99.78429079055786 % 裏の手: 99.9994158744812 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
#
# ここからは129番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.94545865058899 % 裏の手: 99.99963045120239 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは130番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 48.448002338409424 % 裏の手: 99.99475479125977 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは131番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.3752658367157 % 裏の手: 99.97333884239197 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは132番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.0413703918457 % 裏の手: 99.9998688697815 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは133番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 61.80981397628784 % 裏の手: 99.90304708480835 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは134番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 77.72605419158936 % 裏の手: 99.9998927116394 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは135番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.16796088218689 % 裏の手: 99.91888403892517 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは136番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.91170859336853 % 裏の手: 99.99349117279053 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは137番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 63.555508852005005 % 裏の手: 99.99961853027344 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは138番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 60.67665219306946 % 裏の手: 99.99957084655762 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 高橋さんの裏 でした
#
# ここからは139番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 可能性が表の手: 58.249837160110474 % 裏の手: 99.98776912689209 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 高橋さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは140番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.62068796157837 % 裏の手: 99.49945211410522 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは141番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.76383543014526 % 裏の手: 98.42481017112732 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは142番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.7829327583313 % 裏の手: 99.94254112243652 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは143番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.30239915847778 % 裏の手: 96.67845964431763 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは144番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.24925756454468 % 裏の手: 99.30063486099243 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは145番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 87.2012734413147 % 裏の手: 99.84808564186096 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは146番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 92.17149615287781 % 裏の手: 99.55714344978333 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは147番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.70282912254333 % 裏の手: 97.64566421508789 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは148番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.30101323127747 % 裏の手: 99.94595646858215 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
#
# ここからは149番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 89.05775547027588 % 裏の手: 99.99154806137085 %なので認証できません
# 認証の結果は表の手: 田中ひろきさんの表  裏の手: 田中ひろきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは150番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.9106228351593 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは151番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.08797240257263 % 裏の手: 99.99910593032837 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは152番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.5448796749115 % 裏の手: 99.99936819076538 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは153番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 99.5221197605133 % 裏の手: 99.99834299087524 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは154番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.88558292388916 % 裏の手: 99.99951124191284 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは155番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 89.54545855522156 % 裏の手: 99.9990463256836 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは156番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 87.96358108520508 % 裏の手: 99.99995231628418 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは157番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 91.48374795913696 % 裏の手: 99.99973773956299 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは158番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 87.85251379013062 % 裏の手: 99.99995231628418 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
#
# ここからは159番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.65909910202026 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 田中みゆさんの表  裏の手: 田中みゆさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは160番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 76.04507207870483 % 裏の手: 99.99579191207886 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは161番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 可能性が表の手: 98.48889112472534 % 裏の手: 99.99978542327881 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは162番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 96.02420330047607 % 裏の手: 99.99959468841553 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは163番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 91.98694825172424 % 裏の手: 99.9983549118042 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは164番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 97.91471362113953 % 裏の手: 99.99994039535522 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは165番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.85020160675049 % 裏の手: 99.99997615814209 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは166番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.20486807823181 % 裏の手: 99.99690055847168 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは167番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.82941246032715 % 裏の手: 99.99912977218628 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは168番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.52693581581116 % 裏の手: 99.99128580093384 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
#
# ここからは169番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# 可能性が表の手: 99.96559619903564 % 裏の手: 99.99977350234985 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 田中たいきさんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは170番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 40.24287462234497 % 裏の手: 99.99682903289795 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは171番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 26.486095786094666 % 裏の手: 99.30511713027954 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは172番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 24.88352060317993 % 裏の手: 99.97242093086243 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは173番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 68.71519684791565 % 裏の手: 99.99419450759888 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは174番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 58.70945453643799 % 裏の手: 94.54606175422668 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは175番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 39.18341100215912 % 裏の手: 99.98090863227844 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは176番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 40.437787771224976 % 裏の手: 98.72779846191406 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは177番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 39.23634886741638 % 裏の手: 99.9521255493164 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは178番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 53.16087603569031 % 裏の手: 96.62244319915771 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは179番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 36.93813383579254 % 裏の手: 99.86145496368408 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは180番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.57711100578308 % 裏の手: 99.99914169311523 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは181番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.83823299407959 % 裏の手: 99.99980926513672 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは182番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 98.85950684547424 % 裏の手: 99.99994039535522 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは183番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 可能性が表の手: 92.18079447746277 % 裏の手: 99.99934434890747 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは184番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 95.36078572273254 % 裏の手: 99.99990463256836 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは185番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.33975625038147 % 裏の手: 99.99897480010986 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは186番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 99.8816967010498 % 裏の手: 99.99510049819946 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは187番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.13241863250732 % 裏の手: 99.9995231628418 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは188番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.72243309020996 % 裏の手: 99.9988317489624 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは189番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 86.4627480506897 % 裏の手: 99.9995470046997 %なので認証できません
# 認証の結果は表の手: 渡邉さんの表  裏の手: 渡邉さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは190番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.76040720939636 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは191番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.10284471511841 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは192番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 92.65844225883484 % 裏の手: 99.99942779541016 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは193番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 98.96389245986938 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは194番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.81539845466614 % 裏の手: 99.99996423721313 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは195番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.91128706932068 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは196番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.70998954772949 % 裏の手: 99.99254941940308 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは197番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 可能性が表の手: 75.7213294506073 % 裏の手: 99.99784231185913 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは198番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.87071752548218 % 裏の手: 99.99935626983643 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
#
# ここからは199番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 85.72157621383667 % 裏の手: 100.0 %なので認証できません
# 認証の結果は表の手: 山口さんの表  裏の手: 山口さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
# []
# [98.0093240737915, 99.73028898239136, 99.35587048530579, 100.0, 98.83266091346741, 99.99998807907104, 98.13905954360962, 100.0, 99.2186427116394, 99.99997615814209, 60.8864963054657, 99.99998807907104, 98.31425547599792, 99.99514818191528, 98.7544298171997, 100.0, 98.8980770111084, 100.0, 97.94315695762634, 100.0, 83.52978229522705, 99.99922513961792, 86.76815629005432, 99.99948740005493, 90.57281017303467, 99.9998927116394, 94.9633538722992, 99.99922513961792, 78.66669297218323, 99.99409914016724, 86.98002696037292, 99.99994039535522, 92.97783374786377, 99.99971389770508, 95.3215479850769, 99.99369382858276, 93.75462532043457, 99.99994039535522, 90.93403816223145, 99.99992847442627, 99.57069754600525, 99.7465968132019, 99.68260526657104, 99.34648871421814, 99.81154203414917, 99.65066313743591, 99.34725761413574, 92.3269510269165, 99.74752068519592, 99.9887466430664, 99.88707900047302, 99.99600648880005, 99.3636965751648, 99.56902861595154, 98.80006909370422, 95.01668810844421, 99.41902160644531, 94.10178065299988, 99.58299994468689, 99.36196208000183, 66.23193025588989, 99.9439537525177, 96.28767371177673, 99.99991655349731, 98.7562894821167, 99.99985694885254, 99.05258417129517, 99.99992847442627, 92.38966107368469, 100.0, 95.84619998931885, 99.99998807907104, 96.86084985733032, 99.99983310699463, 98.45173954963684, 100.0, 98.79735708236694, 99.99939203262329, 98.24391603469849, 99.99988079071045, 97.3806083202362, 100.0, 96.17477059364319, 99.99996423721313, 98.4312355518341, 100.0, 96.69824838638306, 100.0, 99.56641793251038, 100.0, 99.94761347770691, 99.99998807907104, 99.81005787849426, 99.90039467811584, 99.83202815055847, 99.99998807907104, 99.77012276649475, 99.99985694885254, 97.69207835197449, 99.99992847442627, 95.15829086303711, 99.98258948326111, 83.11919569969177, 100.0, 85.40249466896057, 100.0, 90.97825288772583, 100.0, 90.90001583099365, 100.0, 96.42020463943481, 100.0, 93.89467239379883, 100.0, 99.74864721298218, 100.0, 98.32378625869751, 100.0, 93.78606081008911, 100.0, 99.98817443847656, 99.99995231628418, 99.99645948410034, 100.0, 99.99854564666748, 100.0, 99.99978542327881, 99.99998807907104, 99.99130964279175, 100.0, 99.99498128890991, 100.0, 99.99970197677612, 99.99998807907104, 99.98775720596313, 99.99949932098389, 99.99511241912842, 99.99998807907104, 99.99949932098389, 99.99988079071045, 99.4076132774353, 99.99998807907104, 98.91582727432251, 100.0, 98.6055076122284, 100.0, 86.39832735061646, 99.99997615814209, 95.8056092262268, 99.99998807907104, 99.28991794586182, 99.99929666519165, 99.14355874061584, 99.99998807907104, 99.75252747535706, 99.99996423721313, 99.75361824035645, 99.9998927116394, 74.08103346824646, 99.99943971633911, 99.00982975959778, 99.99983310699463, 98.997563123703, 99.99998807907104, 99.18096661567688, 99.99996423721313, 98.96860718727112, 99.99983310699463, 99.18226599693298, 99.99998807907104, 99.31868314743042, 99.99837875366211, 99.4950532913208, 99.99998807907104, 99.07254576683044, 99.99998807907104, 96.72526717185974, 99.99995231628418, 98.73691201210022, 99.99817609786987, 80.77658414840698, 99.99998807907104, 98.26810956001282, 99.99996423721313, 94.45129632949829, 100.0, 98.50640892982483, 100.0, 95.81335783004761, 99.99967813491821, 90.67053198814392, 99.99951124191284, 95.52181363105774, 99.99998807907104, 98.82656335830688, 99.99104738235474, 73.44976663589478, 100.0, 82.17095732688904, 99.98353719711304, 88.53944540023804, 99.85759258270264, 96.21117115020752, 99.46078062057495, 96.24794721603394, 99.99474287033081, 99.65282082557678, 99.86618757247925, 98.45355153083801, 99.99713897705078, 97.24774360656738, 99.99295473098755, 99.77278113365173, 96.69472575187683, 99.86355900764465, 82.92838931083679, 96.91693186759949, 86.7638111114502, 98.143869638443, 99.98716115951538, 93.02595257759094, 100.0, 96.8599021434784, 99.99995231628418, 99.49209094047546, 100.0, 97.41893410682678, 99.9991774559021, 98.10208082199097, 99.99994039535522, 96.6289758682251, 100.0, 95.0 ...
# -------------------------------------------------------------------
# 閾値以上で識別したテスト数0
# 閾値未満で識別したテスト数400
# 表の手だけで閾値未満で識別したテスト数200
# 裏の手だけで閾値未満で識別したテスト数160
# ================================================
# 本人拒否率100.0%
# 本人受入率0.0%
# 表の手だけを閾値未満で識別した割合100.0%
# 表の手だけを閾値以上で識別した割合0.0%
# 裏の手だけを閾値未満で識別した割合80.0%
# 裏の手だけを閾値以上で識別した割合20.0%
# 閾値以上の最大値は0.0
# []
# 全体の他人受入率は0.3333%
# 2
# 0
