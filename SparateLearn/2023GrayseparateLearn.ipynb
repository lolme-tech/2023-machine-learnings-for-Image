# %%
import numpy as np
from PIL import Image
import cv2
import glob, random
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20FrontGRAY-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023sheetsHands/aizawa/right/omote", 0)
    glob_files("D:/過去の研究データ/2023sheetsHands/arai/right/omote", 1)
    glob_files("D:/過去の研究データ/2023sheetsHands/ebato/right/omote", 2)
    glob_files("D:/過去の研究データ/2023sheetsHands/hasegawa/right/omote", 3)
    glob_files("D:/過去の研究データ/2023sheetsHands/higuchi/right/omote", 4)
    glob_files("D:/過去の研究データ/2023sheetsHands/isii/right/omote", 5)
    glob_files("D:/過去の研究データ/2023sheetsHands/kojima/right/omote", 6)
    glob_files("D:/過去の研究データ/2023sheetsHands/nakamura/right/omote", 7)
    glob_files("D:/過去の研究データ/2023sheetsHands/oono/right/omote", 8)
    glob_files("D:/過去の研究データ/2023sheetsHands/sakai/right/omote", 9)
    glob_files("D:/過去の研究データ/2023sheetsHands/sekine/right/omote", 10)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimada/right/omote", 11)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimizu/right/omote", 12)
    glob_files("D:/過去の研究データ/2023sheetsHands/takahashi/right/omote", 13)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakahiroki/right/omote", 14)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakamiyu/right/omote", 15)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakataiki/right/omote", 16)
    glob_files("D:/過去の研究データ/2023sheetsHands/tokuyama/right/omote", 17)
    glob_files("D:/過去の研究データ/2023sheetsHands/watanabe/right/omote", 18)
    glob_files("D:/過去の研究データ/2023sheetsHands/yamaguchi/right/omote", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1

        #---------Grayscaleの時のプログラム--------------
        img = cv2.imread(f)
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #画像のリサイズ処理
        result_img = cv2.resize(img_gray, (photo_size, photo_size)) 

        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__=='__main__':
    main()
# Out:
# 保存しました:D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20FrontGRAY-128pix.npz 2000
# [[208 208 208 ... 210 212 211]
#  [208 208 208 ... 210 210 210]
#  [208 208 208 ... 213 210 210]
#  ...
#  [192 191 191 ... 185 185 185]
#  [189 188 189 ... 185 183 185]
#  [179 162 159 ... 142 253  25]] 0

# %%
import numpy as np
from PIL import Image
import cv2
import glob, random
# %matplotlib inline

#変更必要
outfile = "D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20BackGRAY-128pix.npz"
#変更必要
photo_size = 128
x = []
y = []

def main():
    glob_files("D:/過去の研究データ/2023sheetsHands/aizawa/right/ura", 0)
    glob_files("D:/過去の研究データ/2023sheetsHands/arai/right/ura", 1)
    glob_files("D:/過去の研究データ/2023sheetsHands/ebato/right/ura", 2)
    glob_files("D:/過去の研究データ/2023sheetsHands/hasegawa/right/ura", 3)
    glob_files("D:/過去の研究データ/2023sheetsHands/higuchi/right/ura", 4)
    glob_files("D:/過去の研究データ/2023sheetsHands/isii/right/ura", 5)
    glob_files("D:/過去の研究データ/2023sheetsHands/kojima/right/ura", 6)
    glob_files("D:/過去の研究データ/2023sheetsHands/nakamura/right/ura", 7)
    glob_files("D:/過去の研究データ/2023sheetsHands/oono/right/ura", 8)
    glob_files("D:/過去の研究データ/2023sheetsHands/sakai/right/ura", 9)
    glob_files("D:/過去の研究データ/2023sheetsHands/sekine/right/ura", 10)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimada/right/ura", 11)
    glob_files("D:/過去の研究データ/2023sheetsHands/shimizu/right/ura", 12)
    glob_files("D:/過去の研究データ/2023sheetsHands/takahashi/right/ura", 13)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakahiroki/right/ura", 14)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakamiyu/right/ura", 15)
    glob_files("D:/過去の研究データ/2023sheetsHands/tanakataiki/right/ura", 16)
    glob_files("D:/過去の研究データ/2023sheetsHands/tokuyama/right/ura", 17)
    glob_files("D:/過去の研究データ/2023sheetsHands/watanabe/right/ura", 18)
    glob_files("D:/過去の研究データ/2023sheetsHands/yamaguchi/right/ura", 19)
    np.savez(outfile, x = x, y = y)
    print("保存しました:" + outfile, len(x))
    print(x[0], y[0])
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    num = 0
    for f in files:
        if num >= len(files): break
        num += 1

        #---------Grayscaleの時のプログラム--------------
        img = cv2.imread(f)
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #画像のリサイズ処理
        result_img = cv2.resize(img_gray, (photo_size, photo_size)) 

        #1つの配列に格納（この場合2つ）
        result_img = np.asarray(result_img) 
        x.append(result_img) 
        y.append(label) 
        
if __name__=='__main__':
    main()
# Out:
# 保存しました:D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20BackGRAY-128pix.npz 2000
# [[211 211 211 ... 214 214 214]
#  [211 210 210 ... 213 213 213]
#  [210 211 211 ... 213 213 213]
#  ...
#  [193 194 194 ... 187 188 190]
#  [193 193 193 ... 186 186 187]
#  [201 187 195 ... 134  54  69]] 0

# %%
# %%time
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    model.summary()
    return model

def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

# 変更必要
im_size = 128
im_color = 1
in_shape = (im_size, im_size, im_color)
nb_classes = 20
hands = "Back"
batch = 256

#変更必要
photos = np.load('D:/過去の研究データ/2023npz/2023UsingFrontAndBackHands/separateLearn/100sheetsNum20' + hands + 'GRAY-' + str(im_size) + 'pix.npz')
x = photos['x']
y = photos['y']

x = x.reshape(-1, im_size, im_size, im_color)
x = x.astype('float32') / 255
y = keras.utils.to_categorical(y.astype('int32'), nb_classes)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size = 0.9)

model = get_model(in_shape, nb_classes)


hist = model.fit(x_train, y_train,
          batch_size = batch, 
          epochs = 20,
          verbose = 1,
          validation_data = (x_test, y_test))

score = model.evaluate(x_test, y_test, verbose = 1)
print('正解率=', score[1], 'loss=', score[0])


plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

#変更必要
model.save_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20' + hands + 'GRAY-' + str(im_size) + 'pixBatch' + str(batch) + '.hdf5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 126, 126, 32)      320
#
#  conv2d_13 (Conv2D)          (None, 124, 124, 32)      9248
#
#  max_pooling2d_6 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  dropout_9 (Dropout)         (None, 62, 62, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 60, 60, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 58, 58, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 29, 29, 64)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 29, 29, 64)        0
#
#  flatten_3 (Flatten)         (None, 53824)             0
#
#  dense_6 (Dense)             (None, 512)               27558400
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 27,633,652
# Trainable params: 27,633,652
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 8/8 [==============================] - 33s 4s/step - loss: 3.6234 - accuracy: 0.0633 - val_loss: 2.9669 - val_accuracy: 0.0750
# Epoch 2/20
# 8/8 [==============================] - 31s 4s/step - loss: 2.9257 - accuracy: 0.1344 - val_loss: 2.8211 - val_accuracy: 0.3950
# Epoch 3/20
# 8/8 [==============================] - 31s 4s/step - loss: 2.6691 - accuracy: 0.3317 - val_loss: 1.7411 - val_accuracy: 0.7800
# Epoch 4/20
# 8/8 [==============================] - 31s 4s/step - loss: 1.6163 - accuracy: 0.6133 - val_loss: 0.8483 - val_accuracy: 0.8600
# Epoch 5/20
# 8/8 [==============================] - 32s 4s/step - loss: 0.3428 - accuracy: 0.9161 - val_loss: 0.0909 - val_accuracy: 0.9750
# Epoch 6/20
# 8/8 [==============================] - 34s 4s/step - loss: 0.1271 - accuracy: 0.9750 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 7/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0225 - accuracy: 0.9944 - val_loss: 0.1779 - val_accuracy: 0.9550
# Epoch 8/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0545 - accuracy: 0.9883 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 9/20
# 8/8 [==============================] - 35s 4s/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 3.0268e-04 - val_accuracy: 1.0000
# Epoch 10/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 3.7420e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 8/8 [==============================] - 34s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.1943e-05 - val_accuracy: 1.0000
# Epoch 12/20
# 8/8 [==============================] - 33s 4s/step - loss: 9.4768e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 13/20
# 8/8 [==============================] - 32s 4s/step - loss: 2.0511 - accuracy: 0.8889 - val_loss: 0.3774 - val_accuracy: 0.9550
# Epoch 14/20
# 8/8 [==============================] - 31s 4s/step - loss: 0.2318 - accuracy: 0.9528 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 15/20
# 8/8 [==============================] - 32s 4s/step - loss: 0.0245 - accuracy: 0.9989 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 16/20
# 8/8 [==============================] - 31s 4s/step - loss: 0.0134 - accuracy: 0.9978 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 17/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 6.1754e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.6354e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1253e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 8/8 [==============================] - 33s 4s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 5.6685e-05 - val_accuracy: 1.0000
# 7/7 [==============================] - 1s 92ms/step - loss: 5.6685e-05 - accuracy: 1.0000
# 正解率= 1.0 loss= 5.668468656949699e-05
# Wall time: 10min 54s

# %%
#他人受入率評価用のプログラム 
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値以上で受入れられた確率が表と裏でそれぞれ格納-----追加1
omotePassPercent = []
uraPassPercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/graytest/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/graytest/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128
im_color = 1
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
min_score = 0.0
omote_thresh = 83.5
ura_thresh = 85.1
batch = "256"

LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)
#変更必要
# model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
# model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 

def findminscore(per):
    global min_score
    if per != 100.0:
        if min_score <= per:
            min_score = per 
            
def check_photo(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #画像のリサイズ
    result_img = cv2.resize(img, (im_size, im_size)) 
    # plt.imshow(result_img, cmap = 'gray')
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < omote_thresh and ("/omote" in path): 
        omoteNotPercent.append(per)
    elif per < ura_thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= omote_thresh and per_ura >= ura_thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        omotePassPercent.append(per_omote)#-----追加3
        uraPassPercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)

        findminscore(per_omote)
        findminscore(per_ura)
    
if __name__ == '__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(omotePassPercent)#-----追加4
    print(uraPassPercent)
    #他人拒否率の配列の中身を表示
    print(omoteNotPercent)
    print(uraNotPercent)
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    omotenotpass = len(omoteNotPercent) / 100
    omotepass = (100 - len(omoteNotPercent)) / 100
    uranotpass = len(uraNotPercent) / 100
    urapass = (100 - len(uraNotPercent)) / 100
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
    # print("表の手だけで未学習の手を閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    # print("表の手だけで未学習の手を閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    # print("裏の手だけで未学習の手を閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    # print("裏の手だけで未学習の手を閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    print("表の手で閾値未満の最大値は" + str(max(omoteNotPercent)))#-----追加5
    print("裏の手で閾値未満の最大値は" + str(max(uraNotPercent)))
    print("表の平均値"+ str(np.mean(omoteNotPercent)))
    print("裏の平均値"+ str(np.mean(uraNotPercent)))
    try:
        print("表の手で閾値以上の最小値は" + str(min(omotePassPercent)))#-----追加6
        print("裏の手で閾値以上の最小値は" + str(min(uraPassPercent)))
    except:
        pass
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 可能性が表の手: 98.76698851585388 % 裏の手: 92.02423095703125 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 88.37727308273315 % 裏の手: 79.78091239929199 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.37740659713745 % 裏の手: 96.30624651908875 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 63.99042010307312 % 裏の手: 45.5139696598053 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 98.9284098148346 % 裏の手: 32.343655824661255 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 83.44166874885559 % 裏の手: 50.58239698410034 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 島田さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 73.66039156913757 % 裏の手: 49.82408285140991 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 78.22197079658508 % 裏の手: 86.36786937713623 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 島田さんの裏 でした
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 78.20819616317749 % 裏の手: 29.91255521774292 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 82.26783871650696 % 裏の手: 56.69354200363159 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 41.755515336990356 % 裏の手: 97.03035354614258 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 でした
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 56.220942735672 % 裏の手: 83.71918797492981 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 でした
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 可能性が表の手: 75.59587359428406 % 裏の手: 31.142401695251465 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 でした
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 51.38777494430542 % 裏の手: 99.88529682159424 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 でした
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 57.92998671531677 % 裏の手: 69.33133602142334 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 でした
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 58.52506160736084 % 裏の手: 68.38090419769287 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 でした
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 68.77643465995789 % 裏の手: 99.95050430297852 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 でした
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 52.22557783126831 % 裏の手: 99.77020621299744 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 可能性が表の手: 44.969841837882996 % 裏の手: 95.84634304046631 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 40.83930850028992 % 裏の手: 84.13351774215698 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 94.95050311088562 % 裏の手: 96.11263275146484 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.75442576408386 % 裏の手: 80.57175874710083 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 83.6382508277893 % 裏の手: 84.62281227111816 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 84.25606489181519 % 裏の手: 99.13290739059448 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 82.82104134559631 % 裏の手: 99.8826801776886 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 97.3835825920105 % 裏の手: 71.36459350585938 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 93.26400756835938 % 裏の手: 97.5480318069458 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 84.47416424751282 % 裏の手: 96.90240025520325 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 88.5582983493805 % 裏の手: 86.41120791435242 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.30762147903442 % 裏の手: 99.16640520095825 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.54106903076172 % 裏の手: 99.99871253967285 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.52024912834167 % 裏の手: 99.99508857727051 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.03134799003601 % 裏の手: 99.99532699584961 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 39.996060729026794 % 裏の手: 99.98983144760132 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 でした
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 99.29611086845398 % 裏の手: 99.99949932098389 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 93.33663582801819 % 裏の手: 99.99998807907104 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 96.09716534614563 % 裏の手: 99.99508857727051 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 54.977619647979736 % 裏の手: 99.99867677688599 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 50.81724524497986 % 裏の手: 99.97554421424866 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 95.87518572807312 % 裏の手: 99.99234676361084 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.1106162071228 % 裏の手: 82.93736577033997 %なので認証できません
# 認証の結果は表の手: 石井さんの表  裏の手: 石井さんの裏 でした
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.94338154792786 % 裏の手: 96.71486020088196 %なので認証します
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.98568296432495 % 裏の手: 99.91098046302795 %なので認証します
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.63615536689758 % 裏の手: 93.21039319038391 %なので認証します
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.32135343551636 % 裏の手: 99.7010350227356 %なので認証します
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.91366267204285 % 裏の手: 95.26538848876953 %なので認証します
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.30260181427002 % 裏の手: 91.23024940490723 %なので認証します
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 84.00270938873291 % 裏の手: 99.98675584793091 %なので認証します
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 87.92764544487 % 裏の手: 99.97164607048035 %なので認証します
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.09967184066772 % 裏の手: 97.50965237617493 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 99.93358254432678 % 裏の手: 62.335312366485596 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.70922470092773 % 裏の手: 56.39503598213196 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.79398512840271 % 裏の手: 86.05045676231384 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 99.56406354904175 % 裏の手: 68.5413122177124 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 97.9343831539154 % 裏の手: 72.96658754348755 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.97738003730774 % 裏の手: 68.33223104476929 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 50.563305616378784 % 裏の手: 92.461496591568 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 87.38572001457214 % 裏の手: 45.453646779060364 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 山口さんの裏 でした
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 52.029794454574585 % 裏の手: 47.7432906627655 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 島田さんの裏 でした
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 47.72112965583801 % 裏の手: 95.20286321640015 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 49.85980987548828 % 裏の手: 42.78477430343628 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99936819076538 % 裏の手: 97.64479994773865 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 99.97803568840027 % 裏の手: 93.50959062576294 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.37264919281006 % 裏の手: 96.90756797790527 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.99992847442627 % 裏の手: 98.65293502807617 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.96939897537231 % 裏の手: 99.90334510803223 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.99992847442627 % 裏の手: 95.21768093109131 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.9779760837555 % 裏の手: 88.07573914527893 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 でした
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.99343156814575 % 裏の手: 72.78373837471008 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99874830245972 % 裏の手: 52.609699964523315 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 新井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 86.443030834198 % 裏の手: 99.64016675949097 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 でした
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 可能性が表の手: 49.03040528297424 % 裏の手: 39.18137550354004 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 山口さんの裏 でした
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 53.99657487869263 % 裏の手: 97.9136049747467 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 98.81836771965027 % 裏の手: 75.52600502967834 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 68.57291460037231 % 裏の手: 99.09999966621399 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 渡邉さんの裏 でした
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 56.322181224823 % 裏の手: 93.64013075828552 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 でした
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 可能性が表の手: 37.391382455825806 % 裏の手: 60.57196855545044 %なので認証できません
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 でした
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 75.1558005809784 % 裏の手: 57.25672245025635 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 でした
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 73.41774106025696 % 裏の手: 94.9747085571289 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 44.234856963157654 % 裏の手: 96.1948573589325 %なので認証できません
# 認証の結果は表の手: 関根さんの表  裏の手: 新井さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 99.95792508125305 % 裏の手: 99.99833106994629 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 可能性が表の手: 99.97077584266663 % 裏の手: 99.94743466377258 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 98.47433567047119 % 裏の手: 99.99321699142456 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.9868392944336 % 裏の手: 99.94251728057861 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.90774393081665 % 裏の手: 99.99512434005737 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.70122575759888 % 裏の手: 99.99709129333496 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 99.96849298477173 % 裏の手: 99.45157170295715 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 87.19319701194763 % 裏の手: 99.96147155761719 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 90.07642269134521 % 裏の手: 99.99895095825195 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.93127584457397 % 裏の手: 99.97001886367798 %なので認証できません
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 84.82388257980347 % 裏の手: 88.26130628585815 %なので認証します
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.91280436515808 % 裏の手: 99.99862909317017 %なので認証します
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 99.97501969337463 % 裏の手: 54.36522364616394 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 68.55553984642029 % 裏の手: 86.1933171749115 %なので認証できません
# 認証の結果は表の手: 新井さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 可能性が表の手: 82.0682168006897 % 裏の手: 67.42815971374512 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 でした
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 80.3400993347168 % 裏の手: 99.99407529830933 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.41387176513672 % 裏の手: 99.96539354324341 %なので認証します
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99688863754272 % 裏の手: 92.8465723991394 %なので認証します
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 58.14517140388489 % 裏の手: 99.99990463256836 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 可能性が表の手: 91.82522296905518 % 裏の手: 49.12106692790985 %なので認証できません
# 認証の結果は表の手: 徳山さんの表  裏の手: 徳山さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
# [99.94338154792786, 99.98568296432495, 99.63615536689758, 99.32135343551636, 99.91366267204285, 99.30260181427002, 84.00270938873291, 87.92764544487, 99.09967184066772, 84.82388257980347, 99.91280436515808, 99.41387176513672, 99.99688863754272]
# [96.71486020088196, 99.91098046302795, 93.21039319038391, 99.7010350227356, 95.26538848876953, 91.23024940490723, 99.98675584793091, 99.97164607048035, 97.50965237617493, 88.26130628585815, 99.99862909317017, 99.96539354324341, 92.8465723991394]
# [63.99042010307312, 83.44166874885559, 73.66039156913757, 78.22197079658508, 78.20819616317749, 82.26783871650696, 41.755515336990356, 56.220942735672, 75.59587359428406, 51.38777494430542, 57.92998671531677, 58.52506160736084, 68.77643465995789, 52.22557783126831, 44.969841837882996, 40.83930850028992, 82.82104134559631, 39.996060729026794, 54.977619647979736, 50.81724524497986, 50.563305616378784, 52.029794454574585, 47.72112965583801, 49.85980987548828, 49.03040528297424, 53.99657487869263, 68.57291460037231, 56.322181224823, 37.391382455825806, 75.1558005809784, 73.41774106025696, 44.234856963157654, 68.55553984642029, 82.0682168006897, 80.3400993347168, 58.14517140388489]
# [79.78091239929199, 45.5139696598053, 32.343655824661255, 50.58239698410034, 49.82408285140991, 29.91255521774292, 56.69354200363159, 83.71918797492981, 31.142401695251465, 69.33133602142334, 68.38090419769287, 84.13351774215698, 80.57175874710083, 84.62281227111816, 71.36459350585938, 82.93736577033997, 62.335312366485596, 56.39503598213196, 68.5413122177124, 72.96658754348755, 68.33223104476929, 45.453646779060364, 47.7432906627655, 42.78477430343628, 72.78373837471008, 52.609699964523315, 39.18137550354004, 75.52600502967834, 60.57196855545044, 57.25672245025635, 54.36522364616394, 67.42815971374512, 49.12106692790985]
# 他人受入に用いる個数26
# 閾値未満で識別したテスト数174
# 表の手だけで閾値未満で識別したテスト数36
# 裏の手だけで閾値未満で識別したテスト数33
# ================================================
# 他人拒否率87.0%
# 他人受入率13.0%
# 表の手で閾値未満の最大値は83.44166874885559
# 裏の手で閾値未満の最大値は84.62281227111816
# 表の平均値60.66760263509221
# 裏の平均値60.43185284643462
# 表の手で閾値以上の最小値は84.00270938873291
# 裏の手で閾値以上の最小値は88.26130628585815

# %%
#本人受入率評価用のプログラム
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
        "arai/right/omote",
        "ebato/right/omote",
        "hasegawa/right/omote",
        "higuchi/right/omote",
        "isii/right/omote",
        "kojima/right/omote",
        "nakamura/right/omote",
        "oono/right/omote",
        "sakai/right/omote",
        "sekine/right/omote",
        "shimada/right/omote",
        "shimizu/right/omote",
        "takahashi/right/omote",
        "tanakahiroki/right/omote",
        "tanakamiyu/right/omote",
        "tanakataiki/right/omote",
        "tokuyama/right/omote",
        "watanabe/right/omote",
        "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
        "arai/right/ura",
        "ebato/right/ura",
        "hasegawa/right/ura",
        "higuchi/right/ura",
        "isii/right/ura",
        "kojima/right/ura",
        "nakamura/right/ura",
        "oono/right/ura",
        "sakai/right/ura",
        "sekine/right/ura",
        "shimada/right/ura",
        "shimizu/right/ura",
        "takahashi/right/ura",
        "tanakahiroki/right/ura",
        "tanakamiyu/right/ura",
        "tanakataiki/right/ura",
        "tokuyama/right/ura",
        "watanabe/right/ura",
        "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#閾値未満ではじかれた確率が表と裏でそれぞれ格納
omoteNotPercent = []
uraNotPercent = []
#閾値以上で受入れられた確率が表と裏でそれぞれ格納-----追加1
omotePassPercent = []
uraPassPercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023graytest/" + str(omote[k]) + "/gray" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023graytest/" + str(ura[k]) + "/gray" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 1
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
#閾値の設定-----追加2
omote_thresh = 83.5
ura_thresh = 85.1
batch = "256"

#学習した人のラベル
LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)

#変更必要
# model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
# model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/2023Num20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')


#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #画像のリサイズ
    result_img = cv2.resize(img, (im_size, im_size))
    #画像の表示
    # plt.imshow(result_img, cmap = 'gray')
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    #閾値(この段階では認証はしないが閾値未満の画像を格納する)
    if per < omote_thresh and ("/omote" in path):
        omoteNotPercent.append(per)
    elif per < ura_thresh and ("/ura" in path):
        uraNotPercent.append(per)
    else:
        pass
    return(idx, per)

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if per_omote >= omote_thresh and per_ura >= ura_thresh and omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "です")
        print("可能性は表の手:", per_omote, "%", "裏の手:", per_ura, "%なので認証します")
        #上記条件を満たしたのに識別を間違えているときの処理
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS_Front[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Front[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS_Back[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Back[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        omotePassPercent.append(per_omote)#-----追加3
        uraPassPercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "可能性が表の手:", per_omote, "% 裏の手:", per_ura, "%なので認証できません" + '\033[0m')
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "でした" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
         
    #本人受入率の配列の中身を表示
    print(omotePassPercent)#-----追加4
    print(uraPassPercent)
    #本人拒否率の配列の中身を表示
    print(omoteNotPercent)
    print(uraNotPercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    print("表の手だけで閾値未満で識別したテスト数" + str(len(omoteNotPercent)))
    print("裏の手だけで閾値未満で識別したテスト数" + str(len(uraNotPercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    omotenotpass = len(omoteNotPercent) / 200
    omotepass = (200 - len(omoteNotPercent)) / 200
    uranotpass = len(uraNotPercent) / 200
    urapass = (200 - len(uraNotPercent)) / 200
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    # print("表の手だけを閾値未満で識別した割合" + str(round(omotenotpass * 100, 4)) + "%")
    # print("表の手だけを閾値以上で識別した割合" + str(round(omotepass * 100, 4)) + "%")
    # print("裏の手だけを閾値未満で識別した割合" + str(round(uranotpass * 100, 4)) + "%")
    # print("裏の手だけを閾値以上で識別した割合" + str(round(urapass * 100, 4)) + "%")
    try:
        print("表の手で閾値未満の最大値は" + str(max(omoteNotPercent)))#-----追加5
        print("裏の手で閾値未満の最大値は" + str(max(uraNotPercent)))
        print("表の平均値"+ str(np.mean(omoteNotPercent)))
        print("裏の平均値"+ str(np.mean(uraNotPercent)))
    except:
        pass
    try:
        print("表の手で閾値以上の最小値は" + str(min(omotePassPercent)))#-----追加6
        print("裏の手で閾値以上の最小値は" + str(min(uraPassPercent)))
    except:
        pass
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
    #他人受入率の算出時に受け入れてしまった個数
    print(FAR)
    #学習済みの人の手の中で他人を受入れてしまった人の個数
    print(len(notIncludeLABEL))
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99792575836182 % 裏の手: 99.98199343681335 %なので認証します
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99890327453613 % 裏の手: 99.9974012374878 %なので認証します
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99618530273438 % 裏の手: 99.9998927116394 %なので認証します
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.98563528060913 % 裏の手: 99.99181032180786 %なので認証します
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99951124191284 % 裏の手: 99.83617663383484 %なので認証します
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 61.12492084503174 % 裏の手: 99.31246638298035 %なので認証できません
# 認証の結果は表の手: 相澤さんの表  裏の手: 相澤さんの裏 でした
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99983310699463 % 裏の手: 99.99992847442627 %なので認証します
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99985694885254 % 裏の手: 99.99983310699463 %なので認証します
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99922513961792 % 裏の手: 99.99936819076538 %なので認証します
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 です
# 可能性は表の手: 99.99022483825684 % 裏の手: 99.99940395355225 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99985694885254 % 裏の手: 99.98334646224976 %なので認証します
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99847412109375 % 裏の手: 99.9987244606018 %なので認証します
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99024868011475 % 裏の手: 99.99853372573853 %なので認証します
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99991655349731 % 裏の手: 99.99853372573853 %なので認証します
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99845027923584 % 裏の手: 99.99878406524658 %なので認証します
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99974966049194 % 裏の手: 99.99606609344482 %なので認証します
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99979734420776 % 裏の手: 99.9794065952301 %なので認証します
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99996423721313 % 裏の手: 99.99959468841553 %なので認証します
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99351501464844 % 裏の手: 99.99833106994629 %なので認証します
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 です
# 可能性は表の手: 99.99728202819824 % 裏の手: 99.99948740005493 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99724626541138 % 裏の手: 99.99983310699463 %なので認証します
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99850988388062 % 裏の手: 99.99979734420776 %なので認証します
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99947547912598 % 裏の手: 99.99703168869019 %なので認証します
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.9988317489624 % 裏の手: 99.99984502792358 %なので認証します
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99502897262573 % 裏の手: 99.99877214431763 %なので認証します
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99972581863403 % 裏の手: 99.99516010284424 %なので認証します
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99849796295166 % 裏の手: 99.99985694885254 %なので認証します
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99803304672241 % 裏の手: 99.99992847442627 %なので認証します
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99867677688599 % 裏の手: 99.9998688697815 %なので認証します
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 です
# 可能性は表の手: 99.99706745147705 % 裏の手: 99.99997615814209 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.70136880874634 % 裏の手: 99.95386600494385 %なので認証します
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99544620513916 % 裏の手: 99.99979734420776 %なので認証します
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99704360961914 % 裏の手: 99.99241828918457 %なので認証します
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99656677246094 % 裏の手: 99.98924732208252 %なので認証します
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99784231185913 % 裏の手: 99.99507665634155 %なので認証します
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99902248382568 % 裏の手: 99.99624490737915 %なので認証します
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99837875366211 % 裏の手: 99.9976396560669 %なので認証します
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.9997615814209 % 裏の手: 99.99103546142578 %なので認証します
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99152421951294 % 裏の手: 99.99619722366333 %なので認証します
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 です
# 可能性は表の手: 99.99898672103882 % 裏の手: 99.99966621398926 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99406337738037 % 裏の手: 99.99960660934448 %なので認証します
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.94800686836243 % 裏の手: 99.99516010284424 %なので認証します
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99029636383057 % 裏の手: 99.99970197677612 %なので認証します
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.97825026512146 % 裏の手: 99.98942613601685 %なので認証します
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99923706054688 % 裏の手: 99.99967813491821 %なので認証します
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.75659847259521 % 裏の手: 99.96793270111084 %なので認証します
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 可能性が表の手: 73.37684035301208 % 裏の手: 99.79827404022217 %なので認証できません
# 認証の結果は表の手: 樋口さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99866485595703 % 裏の手: 99.99971389770508 %なので認証します
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99970197677612 % 裏の手: 99.99982118606567 %なので認証します
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 です
# 可能性は表の手: 99.99884366989136 % 裏の手: 99.99980926513672 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.81061220169067 %なので認証します
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.9996542930603 % 裏の手: 99.99994039535522 %なので認証します
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99936819076538 % 裏の手: 99.99973773956299 %なので認証します
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99996423721313 % 裏の手: 99.99276399612427 %なので認証します
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99945163726807 % 裏の手: 99.99996423721313 %なので認証します
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.9995470046997 % 裏の手: 99.99853372573853 %なので認証します
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99939203262329 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99994039535522 % 裏の手: 99.99992847442627 %なので認証します
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99973773956299 % 裏の手: 99.99966621398926 %なので認証します
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 です
# 可能性は表の手: 99.99988079071045 % 裏の手: 99.9991774559021 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99973773956299 % 裏の手: 99.99018907546997 %なので認証します
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99998807907104 % 裏の手: 100.0 %なので認証します
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99996423721313 % 裏の手: 99.99901056289673 %なので認証します
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 100.0 %なので認証します
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99998807907104 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 100.0 %なので認証します
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99997615814209 % 裏の手: 99.99903440475464 %なので認証します
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99990463256836 % 裏の手: 99.99990463256836 %なので認証します
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 です
# 可能性は表の手: 99.99995231628418 % 裏の手: 99.99969005584717 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.9916672706604 % 裏の手: 99.9512791633606 %なので認証します
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.9994158744812 % 裏の手: 99.99748468399048 %なので認証します
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 93.4518814086914 % 裏の手: 99.99504089355469 %なので認証します
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 72.22347259521484 % 裏の手: 98.71936440467834 %なので認証できません
# 認証の結果は表の手: 中村さんの表  裏の手: 中村さんの裏 でした
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 94.17009353637695 % 裏の手: 99.99858140945435 %なので認証します
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.9795138835907 % 裏の手: 99.98021721839905 %なので認証します
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.91922974586487 % 裏の手: 99.99946355819702 %なので認証します
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.98729228973389 % 裏の手: 99.99762773513794 %なので認証します
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 です
# 可能性は表の手: 99.9957799911499 % 裏の手: 99.99723434448242 %なので認証します
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 62.61444091796875 % 裏の手: 99.9651312828064 %なので認証できません
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 でした
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99979734420776 % 裏の手: 99.99935626983643 %なので認証します
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99923706054688 % 裏の手: 100.0 %なので認証します
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99890327453613 % 裏の手: 99.99988079071045 %なので認証します
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99983310699463 % 裏の手: 100.0 %なので認証します
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99855756759644 % 裏の手: 100.0 %なので認証します
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99960660934448 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.9992847442627 % 裏の手: 100.0 %なので認証します
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99982118606567 % 裏の手: 100.0 %なので認証します
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99814033508301 % 裏の手: 100.0 %なので認証します
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 です
# 可能性は表の手: 99.99922513961792 % 裏の手: 100.0 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.9963641166687 % 裏の手: 99.99299049377441 %なので認証します
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 可能性が表の手: 76.08969211578369 % 裏の手: 99.8002827167511 %なので認証できません
# 認証の結果は表の手: 小島さんの表  裏の手: 坂井さんの裏 でした
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.99922513961792 % 裏の手: 99.94465708732605 %なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.3306577205658 % 裏の手: 99.99229907989502 %なので認証します
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.93035793304443 %なので認証します
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.97832179069519 %なので認証します
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.99979734420776 % 裏の手: 99.98762607574463 %なので認証します
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.99997615814209 % 裏の手: 99.89301562309265 %なので認証します
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.9929428100586 % 裏の手: 99.99960660934448 %なので認証します
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 です
# 可能性は表の手: 99.99880790710449 % 裏の手: 99.97075200080872 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは100番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99761581420898 % 裏の手: 99.98925924301147 %なので認証します
#
# ここからは101番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99841451644897 % 裏の手: 99.99829530715942 %なので認証します
#
# ここからは102番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99130964279175 % 裏の手: 99.99406337738037 %なので認証します
#
# ここからは103番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99721050262451 % 裏の手: 99.99796152114868 %なので認証します
#
# ここからは104番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99431371688843 % 裏の手: 99.99967813491821 %なので認証します
#
# ここからは105番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99940395355225 % 裏の手: 99.9998927116394 %なので認証します
#
# ここからは106番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99620914459229 % 裏の手: 99.99312162399292 %なので認証します
#
# ここからは107番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.9976634979248 % 裏の手: 99.97907280921936 %なので認証します
#
# ここからは108番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.94789958000183 % 裏の手: 99.98490810394287 %なので認証します
#
# ここからは109番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 です
# 可能性は表の手: 99.99257326126099 % 裏の手: 99.98868703842163 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは110番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.97418522834778 % 裏の手: 99.19073581695557 %なので認証します
#
# ここからは111番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99690055847168 % 裏の手: 99.80223178863525 %なので認証します
#
# ここからは112番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.98998641967773 % 裏の手: 100.0 %なので認証します
#
# ここからは113番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99767541885376 % 裏の手: 73.71417880058289 %なので認証できません
# 認証の結果は表の手: 島田さんの表  裏の手: 樋口さんの裏 でした
#
# ここからは114番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.98223185539246 % 裏の手: 98.97247552871704 %なので認証します
#
# ここからは115番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99617338180542 % 裏の手: 99.98395442962646 %なので認証します
#
# ここからは116番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99638795852661 % 裏の手: 99.83515739440918 %なので認証します
#
# ここからは117番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99878406524658 % 裏の手: 99.99996423721313 %なので認証します
#
# ここからは118番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99867677688599 % 裏の手: 99.57755208015442 %なので認証します
#
# ここからは119番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 です
# 可能性は表の手: 99.99483823776245 % 裏の手: 99.99995231628418 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは120番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.98409748077393 % 裏の手: 99.96083378791809 %なので認証します
#
# ここからは121番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99951124191284 % 裏の手: 99.9962329864502 %なので認証します
#
# ここからは122番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99107122421265 % 裏の手: 99.99722242355347 %なので認証します
#
# ここからは123番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.9954104423523 % 裏の手: 99.99477863311768 %なので認証します
#
# ここからは124番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99842643737793 % 裏の手: 99.98797178268433 %なので認証します
#
# ここからは125番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99064207077026 % 裏の手: 99.94282126426697 %なので認証します
#
# ここからは126番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99830722808838 % 裏の手: 99.99959468841553 %なので認証します
#
# ここからは127番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99676942825317 % 裏の手: 99.9953031539917 %なので認証します
#
# ここからは128番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99810457229614 % 裏の手: 99.99176263809204 %なので認証します
#
# ここからは129番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 です
# 可能性は表の手: 99.99595880508423 % 裏の手: 99.990975856781 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは130番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.95809197425842 % 裏の手: 99.99549388885498 %なので認証します
#
# ここからは131番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.99949932098389 % 裏の手: 100.0 %なので認証します
#
# ここからは132番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.99994039535522 % 裏の手: 100.0 %なので認証します
#
# ここからは133番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.99709129333496 % 裏の手: 100.0 %なので認証します
#
# ここからは134番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.9976396560669 % 裏の手: 100.0 %なので認証します
#
# ここからは135番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.9997615814209 % 裏の手: 97.40638732910156 %なので認証します
#
# ここからは136番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 可能性が表の手: 99.99737739562988 % 裏の手: 99.90504384040833 %なので認証できません
# 認証の結果は表の手: 高橋さんの表  裏の手: 徳山さんの裏 でした
#
# ここからは137番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.99593496322632 % 裏の手: 100.0 %なので認証します
#
# ここからは138番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.97894167900085 % 裏の手: 99.99514818191528 %なので認証します
#
# ここからは139番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 です
# 可能性は表の手: 99.99841451644897 % 裏の手: 100.0 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは140番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99947547912598 % 裏の手: 99.99915361404419 %なので認証します
#
# ここからは141番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99992847442627 % 裏の手: 99.9998688697815 %なので認証します
#
# ここからは142番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99679327011108 % 裏の手: 99.9995470046997 %なので認証します
#
# ここからは143番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99995231628418 % 裏の手: 99.99961853027344 %なので認証します
#
# ここからは144番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.9991774559021 % 裏の手: 99.99970197677612 %なので認証します
#
# ここからは145番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.9964714050293 % 裏の手: 99.9974250793457 %なので認証します
#
# ここからは146番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.98412132263184 % 裏の手: 99.99717473983765 %なので認証します
#
# ここからは147番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99998807907104 % 裏の手: 99.99809265136719 %なので認証します
#
# ここからは148番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.99905824661255 % 裏の手: 99.99881982803345 %なので認証します
#
# ここからは149番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 です
# 可能性は表の手: 99.9966025352478 % 裏の手: 99.99847412109375 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは150番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.99996423721313 %なので認証します
#
# ここからは151番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99992847442627 % 裏の手: 99.99953508377075 %なので認証します
#
# ここからは152番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99827146530151 % 裏の手: 98.14938306808472 %なので認証します
#
# ここからは153番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99997615814209 % 裏の手: 97.20436930656433 %なので認証します
#
# ここからは154番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 100.0 % 裏の手: 99.9998927116394 %なので認証します
#
# ここからは155番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99997615814209 % 裏の手: 99.99996423721313 %なので認証します
#
# ここからは156番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99997615814209 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは157番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.98575448989868 % 裏の手: 99.99949932098389 %なので認証します
#
# ここからは158番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99251365661621 % 裏の手: 100.0 %なので認証します
#
# ここからは159番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 です
# 可能性は表の手: 99.99998807907104 % 裏の手: 99.99998807907104 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは160番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.9563992023468 % 裏の手: 100.0 %なので認証します
#
# ここからは161番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99932050704956 % 裏の手: 100.0 %なので認証します
#
# ここからは162番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.9782383441925 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは163番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99972581863403 % 裏の手: 99.99992847442627 %なので認証します
#
# ここからは164番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99251365661621 % 裏の手: 100.0 %なので認証します
#
# ここからは165番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99823570251465 % 裏の手: 100.0 %なので認証します
#
# ここからは166番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99620914459229 % 裏の手: 99.99978542327881 %なので認証します
#
# ここからは167番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.8417615890503 % 裏の手: 99.99971389770508 %なので認証します
#
# ここからは168番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99306201934814 % 裏の手: 99.99953508377075 %なので認証します
#
# ここからは169番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 です
# 可能性は表の手: 99.99973773956299 % 裏の手: 99.99934434890747 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは170番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.9923586845398 % 裏の手: 99.99995231628418 %なので認証します
#
# ここからは171番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99687671661377 % 裏の手: 99.99905824661255 %なので認証します
#
# ここからは172番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99821186065674 % 裏の手: 99.99847412109375 %なので認証します
#
# ここからは173番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99834299087524 % 裏の手: 99.97771382331848 %なので認証します
#
# ここからは174番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.98371601104736 % 裏の手: 99.99997615814209 %なので認証します
#
# ここからは175番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99973773956299 % 裏の手: 99.80080723762512 %なので認証します
#
# ここからは176番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99949932098389 % 裏の手: 99.99988079071045 %なので認証します
#
# ここからは177番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99967813491821 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは178番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.99974966049194 % 裏の手: 99.99873638153076 %なので認証します
#
# ここからは179番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 です
# 可能性は表の手: 99.98985528945923 % 裏の手: 99.99992847442627 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは180番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99703168869019 % 裏の手: 99.99181032180786 %なので認証します
#
# ここからは181番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99656677246094 % 裏の手: 99.99958276748657 %なので認証します
#
# ここからは182番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.75874423980713 % 裏の手: 99.99881982803345 %なので認証します
#
# ここからは183番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99469518661499 % 裏の手: 99.99860525131226 %なので認証します
#
# ここからは184番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.5484471321106 % 裏の手: 99.99933242797852 %なので認証します
#
# ここからは185番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.68717694282532 % 裏の手: 99.9977707862854 %なので認証します
#
# ここからは186番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99090433120728 % 裏の手: 99.99511241912842 %なので認証します
#
# ここからは187番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99977350234985 % 裏の手: 99.99978542327881 %なので認証します
#
# ここからは188番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.99884366989136 % 裏の手: 99.99207258224487 %なので認証します
#
# ここからは189番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 です
# 可能性は表の手: 99.9998927116394 % 裏の手: 99.99896287918091 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは190番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99829530715942 % 裏の手: 100.0 %なので認証します
#
# ここからは191番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99969005584717 % 裏の手: 99.99997615814209 %なので認証します
#
# ここからは192番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99901056289673 % 裏の手: 99.9996542930603 %なので認証します
#
# ここからは193番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99974966049194 % 裏の手: 99.99998807907104 %なので認証します
#
# ここからは194番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99974966049194 % 裏の手: 99.98019337654114 %なので認証します
#
# ここからは195番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99572038650513 % 裏の手: 99.99951124191284 %なので認証します
#
# ここからは196番目の写真です
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99978542327881 % 裏の手: 99.9934434890747 %なので認証します
#
# ここからは197番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99884366989136 % 裏の手: 99.99099969863892 %なので認証します
#
# ここからは198番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99935626983643 % 裏の手: 99.98644590377808 %なので認証します
#
# ここからは199番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 です
# 可能性は表の手: 99.99282360076904 % 裏の手: 99.99991655349731 %なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
# [99.99792575836182, 99.99890327453613, 99.99618530273438, 99.98563528060913, 99.99951124191284, 99.99983310699463, 99.99985694885254, 99.99922513961792, 99.99022483825684, 99.99985694885254, 99.99847412109375, 99.99024868011475, 99.99991655349731, 99.99845027923584, 99.99974966049194, 99.99979734420776, 99.99996423721313, 99.99351501464844, 99.99728202819824, 99.99724626541138, 99.99850988388062, 99.99947547912598, 99.9988317489624, 99.99502897262573, 99.99972581863403, 99.99849796295166, 99.99803304672241, 99.99867677688599, 99.99706745147705, 99.70136880874634, 99.99544620513916, 99.99704360961914, 99.99656677246094, 99.99784231185913, 99.99902248382568, 99.99837875366211, 99.9997615814209, 99.99152421951294, 99.99898672103882, 99.99406337738037, 99.94800686836243, 99.99029636383057, 99.97825026512146, 99.99923706054688, 99.75659847259521, 99.99866485595703, 99.99970197677612, 99.99884366989136, 100.0, 99.9996542930603, 99.99936819076538, 99.99996423721313, 99.99945163726807, 99.9995470046997, 99.99939203262329, 99.99994039535522, 99.99973773956299, 99.99988079071045, 99.99973773956299, 99.99998807907104, 99.99996423721313, 100.0, 100.0, 99.99998807907104, 100.0, 99.99997615814209, 99.99990463256836, 99.99995231628418, 99.9916672706604, 99.9994158744812, 93.4518814086914, 94.17009353637695, 99.9795138835907, 99.91922974586487, 99.98729228973389, 99.9957799911499, 99.99979734420776, 99.99923706054688, 99.99890327453613, 99.99983310699463, 99.99855756759644, 99.99960660934448, 99.9992847442627, 99.99982118606567, 99.99814033508301, 99.99922513961792, 99.9963641166687, 99.99922513961792, 99.3306577205658, 100.0, 100.0, 99.99979734420776, 99.99997615814209, 99.9929428100586, 99.99880790710449, 99.99761581420898, 99.99841451644897, 99.99130964279175, 99.99721050262451, 99.99431371688843, 99.99940395355225, 99.99620914459229, 99.9976634979248, 99.94789958000183, 99.99257326126099, 99.97418522834778, 99.99690055847168, 99.98998641967773, 99.98223185539246, 99.99617338180542, 99.99638795852661, 99.99878406524658, 99.99867677688599, 99.99483823776245, 99.98409748077393, 99.99951124191284, 99.99107122421265, 99.9954104423523, 99.99842643737793, 99.99064207077026, 99.99830722808838, 99.99676942825317, 99.99810457229614, 99.99595880508423, 99.95809197425842, 99.99949932098389, 99.99994039535522, 99.99709129333496, 99.9976396560669, 99.9997615814209, 99.99593496322632, 99.97894167900085, 99.99841451644897, 99.99947547912598, 99.99992847442627, 99.99679327011108, 99.99995231628418, 99.9991774559021, 99.9964714050293, 99.98412132263184, 99.99998807907104, 99.99905824661255, 99.9966025352478, 100.0, 99.99992847442627, 99.99827146530151, 99.99997615814209, 100.0, 99.99997615814209, 99.99997615814209, 99.98575448989868, 99.99251365661621, 99.99998807907104, 99.9563992023468, 99.99932050704956, 99.9782383441925, 99.99972581863403, 99.99251365661621, 99.99823570251465, 99.99620914459229, 99.8417615890503, 99.99306201934814, 99.99973773956299, 99.9923586845398, 99.99687671661377, 99.99821186065674, 99.99834299087524, 99.98371601104736, 99.99973773956299, 99.99949932098389, 99.99967813491821, 99.99974966049194, 99.98985528945923, 99.99703168869019, 99.99656677246094, 99.75874423980713, 99.99469518661499, 99.5484471321106, 99.68717694282532, 99.99090433120728, 99.99977350234985, 99.99884366989136, 99.9998927116394, 99.99829530715942, 99.99969005584717, 99.99901056289673, 99.99974966049194, 99.99974966049194, 99.99572038650513, 99.99978542327881, 99.99884366989136, 99.99935626983643, 99.99282360076904]
# [99.98199343681335, 99.9974012374878, 99.9998927116394, 99.99181032180786, 99.83617663383484, 99.99992847442627, 99.99983310699463, 99.99936819076538, 99.99940395355225, 99.98334646224976, 99.9987244606018, 99.99853372573853, 99.99853372573853, 99.99878406524658, 99.99606609344482, 99.9794065952301, 99.99959468841553, 99.99833106994629, 99.99948740005493, 99.99983310699463, 99.99979734420776, 99.99703168869019, 99.99984502792358, 99.99877214431763, 99.99516010284424, 99.99985694885254, 99.99992847442627, 99.9998688697815, 99.99997615814209, 99.95386600494385, 99.99979734420776, 99.99241828918457, 99.98924732208252, 99.99507665634155, 99.99624490737915, 99.9976396560669, 99.99103546142578, 99.99619722366333, 99.99966621398926, 99.99960660934448, 99.99516010284424, 99.99970197677612, 99.98942613601685, 99.99967813491821, 99.96793270111084, 99.99971389770508, 99.99982118606567, 99.99980926513672, 99.81061220169067, 99.99994039535522, 99.99973773956299, 99.99276399612427, 99.99996423721313, 99.99853372573853, 99.99998807907104, 99.99992847442627, 99.99966621398926, 99.9991774559021, 99.99018907546997, 100.0, 99.99901056289673, 99.99998807907104, 100.0, 99.99998807907104, 100.0, 99.99903440475464, 99.99990463256836, 99.99969005584717, 99.9512791633606, 99.99748468399048, 99.99504089355469, 99.99858140945435, 99.98021721839905, 99.99946355819702, 99.99762773513794, 99.99723434448242, 99.99935626983643, 100.0, 99.99988079071045, 100.0, 100.0, 99.99998807907104, 100.0, 100.0, 100.0, 100.0, 99.99299049377441, 99.94465708732605, 99.99229907989502, 99.93035793304443, 99.97832179069519, 99.98762607574463, 99.89301562309265, 99.99960660934448, 99.97075200080872, 99.98925924301147, 99.99829530715942, 99.99406337738037, 99.99796152114868, 99.99967813491821, 99.9998927116394, 99.99312162399292, 99.97907280921936, 99.98490810394287, 99.98868703842163, 99.19073581695557, 99.80223178863525, 100.0, 98.97247552871704, 99.98395442962646, 99.83515739440918, 99.99996423721313, 99.57755208015442, 99.99995231628418, 99.96083378791809, 99.9962329864502, 99.99722242355347, 99.99477863311768, 99.98797178268433, 99.94282126426697, 99.99959468841553, 99.9953031539917, 99.99176263809204, 99.990975856781, 99.99549388885498, 100.0, 100.0, 100.0, 100.0, 97.40638732910156, 100.0, 99.99514818191528, 100.0, 99.99915361404419, 99.9998688697815, 99.9995470046997, 99.99961853027344, 99.99970197677612, 99.9974250793457, 99.99717473983765, 99.99809265136719, 99.99881982803345, 99.99847412109375, 99.99996423721313, 99.99953508377075, 98.14938306808472, 97.20436930656433, 99.9998927116394, 99.99996423721313, 99.99998807907104, 99.99949932098389, 100.0, 99.99998807907104, 100.0, 100.0, 99.99998807907104, 99.99992847442627, 100.0, 100.0, 99.99978542327881, 99.99971389770508, 99.99953508377075, 99.99934434890747, 99.99995231628418, 99.99905824661255, 99.99847412109375, 99.97771382331848, 99.99997615814209, 99.80080723762512, 99.99988079071045, 99.99998807907104, 99.99873638153076, 99.99992847442627, 99.99181032180786, 99.99958276748657, 99.99881982803345, 99.99860525131226, 99.99933242797852, 99.9977707862854, 99.99511241912842, 99.99978542327881, 99.99207258224487, 99.99896287918091, 100.0, 99.99997615814209, 99.9996542930603, 99.99998807907104, 99.98019337654114, 99.99951124191284, 99.9934434890747, 99.99099969863892, 99.98644590377808, 99.99991655349731]
# [61.12492084503174, 73.37684035301208, 72.22347259521484, 62.61444091796875, 76.08969211578369]
# [73.71417880058289]
# -------------------------------------------------------------------
# 閾値以上で識別したテスト数386
# 閾値未満で識別したテスト数14
# 表の手だけで閾値未満で識別したテスト数5
# 裏の手だけで閾値未満で識別したテスト数1
# ================================================
# 本人拒否率3.5%
# 本人受入率96.5%
# 表の手で閾値未満の最大値は76.08969211578369
# 裏の手で閾値未満の最大値は73.71417880058289
# 表の平均値69.08587336540222
# 裏の平均値73.71417880058289
# 表の手で閾値以上の最小値は93.4518814086914
# 裏の手で閾値以上の最小値は97.20436930656433
# []
# 全体の他人受入率は4.3333%
# 26
# 0

# %%
#他人受入率評価用のプログラム(閾値を用いずに認証)
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#他人受入率用のテスト配列
omote = ["gotou/omote",
        "isii/omote",
        "mimura/omote",
        "nakamura/omote",
        "okutani/omote",
        "saitouhide/omote",
        "saitouryou/omote",
        "sakuma/omote",
        "tanaka/omote",
        "tochikubo/omote"]
ura = ["gotou/ura",
     "isii/ura",
     "mimura/ura",
     "nakamura/ura",
     "okutani/ura",
     "saitouhide/ura",
     "saitouryou/ura",
     "sakuma/ura",
     "tanaka/ura",
     "tochikubo/ura"]

#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []

#target_omoteに表の画像を入れ、target_uraに裏の画像を入れる
#変更必要
for k in range(10):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/graytest/" + str(omote[k]) + "/" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/graytest/" + str(ura[k]) + "/" + str(i) + ".jpg")
        
#変更必要
im_size = 128
im_color = 1
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
batch = "256"

LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)
#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')

#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per 
            
def check_photo(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #画像のリサイズ
    result_img = cv2.resize(img, (im_size, im_size)) 
    # plt.imshow(result_img, cmap = 'gray')
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    return (idx, per)

def check_photo_str(path_omote, path_ura):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "なので認証します")

        #誤って他人を受入れてしまった確率を配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "なので認証できません" + '\033[0m')
        #正しく他人を拒否した確率を配列に格納する
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__ == '__main__':
    for i in range(100):
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i])
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("グレイスケール画像 " + str(im_size) + "px バッチサイズ" + str(batch))
    print("他人受入に用いる個数" + str(len(passpercent)))
    #全体の他人受入率算出用に変数FARに他人受入の個数を格納
    FAR = len(passpercent)
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    #表裏合計、それぞれの他人受入(拒否)率を算出する
    totalpass = len(passpercent) / 200
    totalnotpass = len(notpasspercent) / 200
    print("================================================")
    #未学習の手を閾値未満で識別した割合
    print("他人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #未学習の手を閾値以上で識別した割合
    print("他人受入率" + str(round(totalpass * 100, 4)) + "%")
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 石井さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 なので認証できません
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 なので認証できません
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 なので認証できません
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 石井さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 清水さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 山口さんの裏 なので認証できません
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 相澤さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 関根さんの裏 なので認証できません
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 新井さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 山口さんの裏 なので認証できません
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 渡邉さんの裏 なので認証できません
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 清水さんの表  裏の手: 新井さんの裏 なので認証できません
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 島田さんの裏 なので認証できません
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 相澤さんの裏 なので認証できません
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 関根さんの表  裏の手: 新井さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 認証の結果は表の手: 田中たいきさんの表  裏の手: 大野さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 認証の結果は表の手: 新井さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 認証の結果は表の手: 徳山さんの表  裏の手: 長谷川さんの裏 なので認証できません
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
# [98.1106162071228, 82.93736577033997, 99.94338154792786, 96.71486020088196, 99.98568296432495, 99.91098046302795, 99.63615536689758, 93.21039319038391, 99.32135343551636, 99.7010350227356, 99.91366267204285, 95.26538848876953, 99.30260181427002, 91.23024940490723, 84.00270938873291, 99.98675584793091, 87.92764544487, 99.97164607048035, 99.09967184066772, 97.50965237617493, 49.85980987548828, 42.78477430343628, 84.82388257980347, 88.26130628585815, 99.91280436515808, 99.99862909317017, 99.97501969337463, 54.36522364616394, 80.3400993347168, 99.99407529830933, 99.41387176513672, 99.96539354324341, 99.99688863754272, 92.8465723991394, 58.14517140388489, 99.99990463256836, 91.82522296905518, 49.12106692790985]
# [98.76698851585388, 92.02423095703125, 88.37727308273315, 79.78091239929199, 98.37740659713745, 96.30624651908875, 63.99042010307312, 45.5139696598053, 98.9284098148346, 32.343655824661255, 83.44166874885559, 50.58239698410034, 73.66039156913757, 49.82408285140991, 78.22197079658508, 86.36786937713623, 78.20819616317749, 29.91255521774292, 82.26783871650696, 56.69354200363159, 41.755515336990356, 97.03035354614258, 56.220942735672, 83.71918797492981, 75.59587359428406, 31.142401695251465, 51.38777494430542, 99.88529682159424, 57.92998671531677, 69.33133602142334, 58.52506160736084, 68.38090419769287, 68.77643465995789, 99.95050430297852, 52.22557783126831, 99.77020621299744, 44.969841837882996, 95.84634304046631, 40.83930850028992, 84.13351774215698, 94.95050311088562, 96.11263275146484, 96.75442576408386, 80.57175874710083, 83.6382508277893, 84.62281227111816, 84.25606489181519, 99.13290739059448, 82.82104134559631, 99.8826801776886, 97.3835825920105, 71.36459350585938, 93.26400756835938, 97.5480318069458, 84.47416424751282, 96.90240025520325, 88.5582983493805, 86.41120791435242, 98.30762147903442, 99.16640520095825, 98.54106903076172, 99.99871253967285, 98.52024912834167, 99.99508857727051, 98.03134799003601, 99.99532699584961, 39.996060729026794, 99.98983144760132, 99.29611086845398, 99.99949932098389, 93.33663582801819, 99.99998807907104, 96.09716534614563, 99.99508857727051, 54.977619647979736, 99.99867677688599, 50.81724524497986, 99.97554421424866, 95.87518572807312, 99.99234676361084, 99.93358254432678, 62.335312366485596, 99.70922470092773, 56.39503598213196, 90.79398512840271, 86.05045676231384, 99.56406354904175, 68.5413122177124, 97.9343831539154, 72.96658754348755, 99.97738003730774, 68.33223104476929, 50.563305616378784, 92.461496591568, 87.38572001457214, 45.453646779060364, 52.029794454574585, 47.7432906627655, 47.72112965583801, 95.20286321640015, 99.99936819076538, 97.64479994773865, 99.97803568840027, 93.50959062576294, 99.37264919281006, 96.90756797790527, 99.99992847442627, 98.65293502807617, 99.96939897537231, 99.90334510803223, 99.99992847442627, 95.21768093109131, 99.9779760837555, 88.07573914527893, 99.99343156814575, 72.78373837471008, 99.99874830245972, 52.609699964523315, 86.443030834198, 99.64016675949097, 49.03040528297424, 39.18137550354004, 53.99657487869263, 97.9136049747467, 98.81836771965027, 75.52600502967834, 68.57291460037231, 99.09999966621399, 56.322181224823, 93.64013075828552, 37.391382455825806, 60.57196855545044, 75.1558005809784, 57.25672245025635, 73.41774106025696, 94.9747085571289, 44.234856963157654, 96.1948573589325, 99.95792508125305, 99.99833106994629, 99.97077584266663, 99.94743466377258, 98.47433567047119, 99.99321699142456, 99.9868392944336, 99.94251728057861, 99.90774393081665, 99.99512434005737, 99.70122575759888, 99.99709129333496, 99.96849298477173, 99.45157170295715, 87.19319701194763, 99.96147155761719, 90.07642269134521, 99.99895095825195, 99.93127584457397, 99.97001886367798, 68.55553984642029, 86.1933171749115, 82.0682168006897, 67.42815971374512]
# グレイスケール画像 128px バッチサイズ256
# 他人受入に用いる個数38
# 閾値未満で識別したテスト数162
# ================================================
# 他人拒否率81.0%
# 他人受入率19.0%

# %%
#本人受入率評価用のプログラム(閾値を用いずに認証)
import math
import keras 
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size = (3, 3),
              activation = 'relu',
              input_shape = in_shape))
    model.add(Conv2D(32, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(Conv2D(64, (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation = 'softmax'))
    return model


def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = RMSprop(),
        metrics = ['accuracy'])
    return model

#学習済みの人の評価画像
omote = ["aizawa/right/omote",
        "arai/right/omote",
        "ebato/right/omote",
        "hasegawa/right/omote",
        "higuchi/right/omote",
        "isii/right/omote",
        "kojima/right/omote",
        "nakamura/right/omote",
        "oono/right/omote",
        "sakai/right/omote",
        "sekine/right/omote",
        "shimada/right/omote",
        "shimizu/right/omote",
        "takahashi/right/omote",
        "tanakahiroki/right/omote",
        "tanakamiyu/right/omote",
        "tanakataiki/right/omote",
        "tokuyama/right/omote",
        "watanabe/right/omote",
        "yamaguchi/right/omote"]
ura = ["aizawa/right/ura",
        "arai/right/ura",
        "ebato/right/ura",
        "hasegawa/right/ura",
        "higuchi/right/ura",
        "isii/right/ura",
        "kojima/right/ura",
        "nakamura/right/ura",
        "oono/right/ura",
        "sakai/right/ura",
        "sekine/right/ura",
        "shimada/right/ura",
        "shimizu/right/ura",
        "takahashi/right/ura",
        "tanakahiroki/right/ura",
        "tanakamiyu/right/ura",
        "tanakataiki/right/ura",
        "tokuyama/right/ura",
        "watanabe/right/ura",
        "yamaguchi/right/ura"]
#表の評価画像と裏の評価画像のパスが格納
target_omote = []
target_ura = []
#誤って他人を受入れてしまった確率が格納
passpercent = []
#正しく他人を拒否した確率が格納
notpasspercent = []
#学習済みの人の中で他人を受入れた場合の警告表示が格納
notIncludeLABEL = []

#変更必要
for k in range(20):
    for i in range(10):
        target_omote.append("D:/過去の研究データ/2023graytest/" + str(omote[k]) + "/gray" + str(i) + ".jpg")
        target_ura.append("D:/過去の研究データ/2023graytest/" + str(ura[k]) + "/gray" + str(i) + ".jpg")

#変更必要
im_size = 128
im_color = 1
in_shape = (im_size, im_size, im_color)
nb_classes = 20
#配列の最大値
max_score = 0.0
batch = "256"

#学習した人のラベル
LABELS_Front = ["相澤さんの表", "新井さんの表",
                "江波戸の表", "長谷川さんの表",
                "樋口さんの表", "石井さんの表",
                "小島さんの表", "中村さんの表",
                "大野さんの表", "坂井さんの表",
                "関根さんの表", "島田さんの表",
                "清水さんの表", "高橋さんの表",
                "田中ひろきさんの表", "田中みゆさんの表",
                "田中たいきさんの表", "徳山さんの表",
                "渡邉さんの表", "山口さんの表",]
LABELS_Back = ["相澤さんの裏", "新井さんの裏",
                "江波戸の裏", "長谷川さんの裏",
                "樋口さんの裏", "石井さんの裏",
                "小島さんの裏", "中村さんの裏",
                "大野さんの裏", "坂井さんの裏",
                "関根さんの裏", "島田さんの裏",
                "清水さんの裏", "高橋さんの裏",
                "田中ひろきさんの裏", "田中みゆさんの裏",
                "田中たいきさんの裏", "徳山さんの裏",
                "渡邉さんの裏", "山口さんの裏"]
#確定ラベル
AbsLABELS = ["相澤さん", "新井さん", "江波戸", "長谷川さん",
             "樋口さん", "石井さん", "小島さん", "中村さん",
             "大野さん", "坂井さん", "関根さん", "島田さん",
             "清水さん", "高橋さん", "田中ひろきさん", "田中みゆさん",
             "田中たいきさん", "徳山さん", "渡邉さん",  "山口さん"]

model_front = get_model(in_shape, nb_classes)
model_back = get_model(in_shape, nb_classes)

#変更必要
model_front.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20FrontGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')
model_back.load_weights('D:/過去の研究データ/2023hdf/2023separateLearn/100sheetsNum20BackGRAY-' + str(im_size) + 'pixBatch' + batch + '.hdf5')


#評価画像の確率を受け取り、max_scoreよりも大きい値をmax_scoreとして更新する
def findmaxscore(per):
    global max_score
    if per != 100.0:
        if max_score <= per:
            max_score = per
                
def check_photo(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #画像のリサイズ
    result_img = cv2.resize(img, (im_size, im_size))
    #画像の表示
    # plt.imshow(result_img, cmap = 'gray')
    # plt.show()

    x = np.asarray(result_img)
    x = x.reshape(-1, im_size, im_size, im_color)
    x = x / 255
    
    #画像の予測
    if "/omote" in path:
        pre = model_front.predict([x])[0]
    elif "/ura" in path:
        pre = model_back.predict([x])[0]
    idx = pre.argmax()
    per = (pre[idx] * 100)
    return(idx, per)

def check_photo_str(path_omote, path_ura, i):
    idx_omote, per_omote = check_photo(path_omote)
    idx_ura, per_ura = check_photo(path_ura)
    #Aさんの表を「Aさん」と「表」に分割する
    omotePerson = LABELS_Front[idx_omote].split("の")
    uraPerson = LABELS_Back[idx_ura].split("の")
    #表の評価画像と裏の評価画像が閾値以上かつ人の名前が一致しているかつ表裏の評価画像が表と裏で一致しているかの判定
    if omotePerson[0] == uraPerson[0] and omotePerson[1] == "表" and uraPerson[1] == "裏":
        print("この手は表:", LABELS_Front[idx_omote], "裏:", LABELS_Back[idx_ura], "なので認証します")
        #上記条件を満たしたのに識別を間違えているときの処理
        if i < 10:
            ConfLABEL = AbsLABELS[0]
        elif i < 20:
            ConfLABEL = AbsLABELS[1]
        elif i < 30:
            ConfLABEL = AbsLABELS[2]
        elif i < 40:
            ConfLABEL = AbsLABELS[3]
        elif i < 50:
            ConfLABEL = AbsLABELS[4]
        elif i < 60:
            ConfLABEL = AbsLABELS[5]
        elif i < 70:
            ConfLABEL = AbsLABELS[6]
        elif i < 80:
            ConfLABEL = AbsLABELS[7]
        elif i < 90:
            ConfLABEL = AbsLABELS[8]
        elif i < 100:
            ConfLABEL = AbsLABELS[9]
        elif i < 110:
            ConfLABEL = AbsLABELS[10]
        elif i < 120:
            ConfLABEL = AbsLABELS[11]
        elif i < 130:
            ConfLABEL = AbsLABELS[12]
        elif i < 140:
            ConfLABEL = AbsLABELS[13]
        elif i < 150:
            ConfLABEL = AbsLABELS[14]
        elif i < 160:
            ConfLABEL = AbsLABELS[15]
        elif i < 170:
            ConfLABEL = AbsLABELS[16]
        elif i < 180:
            ConfLABEL = AbsLABELS[17]
        elif i < 190:
            ConfLABEL = AbsLABELS[18]
        elif i < 200:
            ConfLABEL = AbsLABELS[19]

        if ConfLABEL not in LABELS_Front[idx_omote] :
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Front[idx_omote] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')
        if ConfLABEL not in LABELS_Back[idx_ura]:
            notIncludeLABEL.append("-" + ConfLABEL + "を" + LABELS_Back[idx_ura] + "だと誤認識-")  
            print('\033[31m' + '識別エラーが起きています' + '\033[0m')

        #本人受入の配列に格納
        passpercent.append(per_omote)
        passpercent.append(per_ura)
        
        #max_scoreよりも大きい確率かどうかを判定する
        findmaxscore(per_omote)
        findmaxscore(per_ura)
        
    else:
        print('\033[31m' + "認証の結果は表の手:", LABELS_Front[idx_omote], " 裏の手:", LABELS_Back[idx_ura], "なので認証できません" + '\033[0m')
        #誤って本人を拒否してしまった人の確率を配列に格納
        notpasspercent.append(per_omote)
        notpasspercent.append(per_ura)
    
if __name__=='__main__':
    #学習人数が増えたらiのrangeを変更必要
    for i in range(200): 
        print("\nここからは" + str(i) + "番目の写真です")
        #表と裏の評価画像を渡して認証を行う
        check_photo_str(target_omote[i], target_ura[i], i)
        if i % 10 == 9:
            print("================================================")
            print("テスト対象の人が変わります")
            print("================================================")
         
    #他人受入率の配列の中身を表示
    print(passpercent)
    #他人拒否率の配列の中身を表示
    print(notpasspercent)
    print("-------------------------------------------------------------------")   
    print("閾値以上で識別したテスト数" + str(len(passpercent)))
    print("閾値未満で識別したテスト数" + str(len(notpasspercent)))
    totalpass = len(passpercent) / 400
    totalnotpass = len(notpasspercent) / 400
    print("================================================")
    #学習済みの人の手を閾値未満で識別した割合
    print("本人拒否率" + str(round(totalnotpass * 100, 4)) + "%")
    #学習済みの人の手を閾値以上で識別した割合
    print("本人受入率" + str(round(totalpass * 100, 4)) + "%")
    #他人受入率の評価と本人拒否率の評価すべてにおける他人受入
    print(notIncludeLABEL)
    print("全体の他人受入率は" + str(round((FAR + len(notIncludeLABEL)) / 600 * 100, 4)) + "%")
# Out:
# ここからは0番目の写真です
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 76ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは1番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは2番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは3番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは4番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは5番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは6番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは7番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは8番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
#
# ここからは9番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 相澤さんの表 裏: 相澤さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは10番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは11番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは12番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは13番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは14番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは15番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは16番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは17番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは18番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
#
# ここからは19番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 新井さんの表 裏: 新井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは20番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは21番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは22番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは23番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは24番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは25番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは26番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは27番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは28番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
#
# ここからは29番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 江波戸の表 裏: 江波戸の裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは30番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは31番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは32番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは33番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは34番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは35番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは36番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは37番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは38番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
#
# ここからは39番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 長谷川さんの表 裏: 長谷川さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは40番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは41番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは42番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは43番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは44番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは45番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは46番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは47番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは48番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
#
# ここからは49番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 樋口さんの表 裏: 樋口さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは50番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは51番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは52番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは53番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは54番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは55番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは56番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは57番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは58番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
#
# ここからは59番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 石井さんの表 裏: 石井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは60番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは61番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは62番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは63番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは64番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは65番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは66番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは67番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは68番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
#
# ここからは69番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 小島さんの表 裏: 小島さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは70番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは71番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは72番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは73番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは74番目の写真です
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは75番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは76番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは77番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは78番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 中村さんの表 裏: 中村さんの裏 なので認証します
#
# ここからは79番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 長谷川さんの表  裏の手: 中村さんの裏 なので認証できません
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは80番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは81番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは82番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは83番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは84番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは85番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは86番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは87番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは88番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
#
# ここからは89番目の写真です
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 大野さんの表 裏: 大野さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは90番目の写真です
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 49ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは91番目の写真です
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 64ms/step
# 認証の結果は表の手: 小島さんの表  裏の手: 坂井さんの裏 なので認証できません
#
# ここからは92番目の写真です
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは93番目の写真です
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは94番目の写真です
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは95番目の写真です
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは96番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは97番目の写真です
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは98番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
#
# ここからは99番目の写真です
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# この手は表: 坂井さんの表 裏: 坂井さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは100番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは101番目の写真です
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは102番目の写真です
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは103番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは104番目の写真です
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは105番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは106番目の写真です
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは107番目の写真です
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは108番目の写真です
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
#
# ここからは109番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# この手は表: 関根さんの表 裏: 関根さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは110番目の写真です
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは111番目の写真です
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは112番目の写真です
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは113番目の写真です
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 認証の結果は表の手: 島田さんの表  裏の手: 樋口さんの裏 なので認証できません
#
# ここからは114番目の写真です
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは115番目の写真です
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは116番目の写真です
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 63ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは117番目の写真です
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは118番目の写真です
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
#
# ここからは119番目の写真です
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 島田さんの表 裏: 島田さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは120番目の写真です
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは121番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは122番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは123番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは124番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは125番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは126番目の写真です
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは127番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは128番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
#
# ここからは129番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# この手は表: 清水さんの表 裏: 清水さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは130番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは131番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは132番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは133番目の写真です
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは134番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは135番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは136番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 認証の結果は表の手: 高橋さんの表  裏の手: 徳山さんの裏 なので認証できません
#
# ここからは137番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは138番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
#
# ここからは139番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 高橋さんの表 裏: 高橋さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは140番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは141番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは142番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは143番目の写真です
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは144番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは145番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは146番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは147番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは148番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
#
# ここからは149番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中ひろきさんの表 裏: 田中ひろきさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは150番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは151番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは152番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 48ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは153番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは154番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは155番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは156番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは157番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは158番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
#
# ここからは159番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 田中みゆさんの表 裏: 田中みゆさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは160番目の写真です
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは161番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは162番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは163番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは164番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは165番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは166番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは167番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは168番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
#
# ここからは169番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# この手は表: 田中たいきさんの表 裏: 田中たいきさんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは170番目の写真です
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは171番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは172番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは173番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは174番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは175番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは176番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは177番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは178番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
#
# ここからは179番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 徳山さんの表 裏: 徳山さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは180番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは181番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは182番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは183番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは184番目の写真です
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは185番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは186番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは187番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは188番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
#
# ここからは189番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 渡邉さんの表 裏: 渡邉さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
#
# ここからは190番目の写真です
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは191番目の写真です
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは192番目の写真です
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは193番目の写真です
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは194番目の写真です
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは195番目の写真です
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは196番目の写真です
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは197番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは198番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
#
# ここからは199番目の写真です
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# この手は表: 山口さんの表 裏: 山口さんの裏 なので認証します
# ================================================
# テスト対象の人が変わります
# ================================================
# [99.99792575836182, 99.98199343681335, 99.99890327453613, 99.9974012374878, 99.99618530273438, 99.9998927116394, 99.98563528060913, 99.99181032180786, 99.99951124191284, 99.83617663383484, 61.12492084503174, 99.31246638298035, 99.99983310699463, 99.99992847442627, 99.99985694885254, 99.99983310699463, 99.99922513961792, 99.99936819076538, 99.99022483825684, 99.99940395355225, 99.99985694885254, 99.98334646224976, 99.99847412109375, 99.9987244606018, 99.99024868011475, 99.99853372573853, 99.99991655349731, 99.99853372573853, 99.99845027923584, 99.99878406524658, 99.99974966049194, 99.99606609344482, 99.99979734420776, 99.9794065952301, 99.99996423721313, 99.99959468841553, 99.99351501464844, 99.99833106994629, 99.99728202819824, 99.99948740005493, 99.99724626541138, 99.99983310699463, 99.99850988388062, 99.99979734420776, 99.99947547912598, 99.99703168869019, 99.9988317489624, 99.99984502792358, 99.99502897262573, 99.99877214431763, 99.99972581863403, 99.99516010284424, 99.99849796295166, 99.99985694885254, 99.99803304672241, 99.99992847442627, 99.99867677688599, 99.9998688697815, 99.99706745147705, 99.99997615814209, 99.70136880874634, 99.95386600494385, 99.99544620513916, 99.99979734420776, 99.99704360961914, 99.99241828918457, 99.99656677246094, 99.98924732208252, 99.99784231185913, 99.99507665634155, 99.99902248382568, 99.99624490737915, 99.99837875366211, 99.9976396560669, 99.9997615814209, 99.99103546142578, 99.99152421951294, 99.99619722366333, 99.99898672103882, 99.99966621398926, 99.99406337738037, 99.99960660934448, 99.94800686836243, 99.99516010284424, 99.99029636383057, 99.99970197677612, 99.97825026512146, 99.98942613601685, 99.99923706054688, 99.99967813491821, 99.75659847259521, 99.96793270111084, 73.37684035301208, 99.79827404022217, 99.99866485595703, 99.99971389770508, 99.99970197677612, 99.99982118606567, 99.99884366989136, 99.99980926513672, 100.0, 99.81061220169067, 99.9996542930603, 99.99994039535522, 99.99936819076538, 99.99973773956299, 99.99996423721313, 99.99276399612427, 99.99945163726807, 99.99996423721313, 99.9995470046997, 99.99853372573853, 99.99939203262329, 99.99998807907104, 99.99994039535522, 99.99992847442627, 99.99973773956299, 99.99966621398926, 99.99988079071045, 99.9991774559021, 99.99973773956299, 99.99018907546997, 99.99998807907104, 100.0, 99.99996423721313, 99.99901056289673, 100.0, 99.99998807907104, 100.0, 100.0, 99.99998807907104, 99.99998807907104, 100.0, 100.0, 99.99997615814209, 99.99903440475464, 99.99990463256836, 99.99990463256836, 99.99995231628418, 99.99969005584717, 99.9916672706604, 99.9512791633606, 99.9994158744812, 99.99748468399048, 93.4518814086914, 99.99504089355469, 72.22347259521484, 98.71936440467834, 94.17009353637695, 99.99858140945435, 99.9795138835907, 99.98021721839905, 99.91922974586487, 99.99946355819702, 99.98729228973389, 99.99762773513794, 99.9957799911499, 99.99723434448242, 99.99979734420776, 99.99935626983643, 99.99923706054688, 100.0, 99.99890327453613, 99.99988079071045, 99.99983310699463, 100.0, 99.99855756759644, 100.0, 99.99960660934448, 99.99998807907104, 99.9992847442627, 100.0, 99.99982118606567, 100.0, 99.99814033508301, 100.0, 99.99922513961792, 100.0, 99.9963641166687, 99.99299049377441, 99.99922513961792, 99.94465708732605, 99.3306577205658, 99.99229907989502, 100.0, 99.93035793304443, 100.0, 99.97832179069519, 99.99979734420776, 99.98762607574463, 99.99997615814209, 99.89301562309265, 99.9929428100586, 99.99960660934448, 99.99880790710449, 99.97075200080872, 99.99761581420898, 99.98925924301147, 99.99841451644897, 99.99829530715942, 99.99130964279175, 99.99406337738037, 99.99721050262451, 99.99796152114868, 99.99431371688843, 99.99967813491821, 99.99940395355225, 99.9998927116394, 99.99620914459229, 99.99312162399292, 99.9976634979248, 99.97907280921936, 99.94789958000183, 99.98490810394287, 99.99257326126099, 99.98868703842163, 99.97418522834778, 99.19073581695557, 99.99690055847168, 99.80223178863525, 99.98998641967773, 100.0, 99.98223 ...
# [62.61444091796875, 99.9651312828064, 76.08969211578369, 99.8002827167511, 99.99767541885376, 73.71417880058289, 99.99737739562988, 99.90504384040833]
# -------------------------------------------------------------------
# 閾値以上で識別したテスト数392
# 閾値未満で識別したテスト数8
# ================================================
# 本人拒否率2.0%
# 本人受入率98.0%
# []
# 全体の他人受入率は6.3333%
